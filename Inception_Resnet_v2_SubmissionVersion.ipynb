# %% [markdown]
# <a href="https://colab.research.google.com/github/eteral00/UNT_CSCE5218_Project_DogsBreeds/blob/main/Inception_Resnet_v2_SubmissionVersion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mounting GoogleDrive**
# You will need to add a shortcut to this Google shared folder to your own Google Drive to be able to access the dataset, the saved models, nad saved output statistics: \\
# https://drive.google.com/drive/folders/1IypaLVub6Mk9A0AO_hN3wv5yEY04JNin
#
# As well as going through this list of shared folders so that your drive recognized you have access to them (they are allshared as "has-link-can-view", but your GGDrive still need to recognize that you have the access) \\
# https://drive.google.com/drive/folders/18QH_EOzL4halbKdHtDBil-De9Ia_Ys1d
#
# https://drive.google.com/drive/folders/1Q2AhR6p28aD6J57ICYipuwvPgCgLoj1t
#
# https://drive.google.com/drive/folders/1O75reXnX9LOT6LusUM1KUN6X8DlDor6S

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Handling data**

# %% [markdown]
# ## Dataset: Tsinghua Dogs:
# Main link: https://cg.cs.tsinghua.edu.cn/ThuDogs/ \\
# Lower resolution version (~2.5GBs): https://cloud.tsinghua.edu.cn/f/80013ef29c5f42728fc8/

# %% [markdown]
# ## Decompress

# %%
# !unzip "/content/drive/MyDrive/CSCE5218/Dog_Breed_classification/Dog_Breed_dataset/Tshihua/low-resolution.zip" -d "/content/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/low-resolution/7449-n000128-teddy/n165759.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165760.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165761.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165762.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165763.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165764.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165765.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165766.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165767.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165768.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165769.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165770.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165771.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165772.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165773.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165774.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165775.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165776.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165777.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165778.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165779.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165780.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165781.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165782.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165783.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165784.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165785.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165786.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165787.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165788.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165789.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165790.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165791.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165792.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165793.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165794.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165795.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165796.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165797.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165798.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165799.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165800.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165801.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165802.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165803.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165804.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165805.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165806.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165807.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165808.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165809.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165810.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165811.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165812.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165813.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165814.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165815.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165816.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165817.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165818.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165819.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165820.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165821.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165822.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165823.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165824.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165825.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165826.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165827.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165828.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165829.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165830.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165831.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165832.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165833.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165834.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165835.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165836.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165837.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165838.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165839.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165840.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165841.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165842.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165843.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165844.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165845.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165846.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165847.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165848.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165849.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165850.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165851.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165852.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165853.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165854.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165855.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165856.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165857.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165858.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165859.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165860.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165861.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165862.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165863.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165864.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165865.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165866.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165867.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165868.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165869.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165870.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165871.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165872.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165873.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165874.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165875.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165876.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165877.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165878.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165879.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165880.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165881.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165882.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165883.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165884.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165885.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165886.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165887.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165888.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165889.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165890.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165891.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165892.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165893.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165894.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165895.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165896.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165897.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165898.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165899.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165900.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165901.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165902.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165903.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165904.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165905.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165906.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165907.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165908.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165909.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165910.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165911.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165912.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165913.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165914.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165915.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165916.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165917.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165918.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165919.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165920.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165921.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165922.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165923.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165924.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165925.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165926.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165927.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165928.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165929.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165930.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165931.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165932.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165933.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165934.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165935.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165936.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165937.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165938.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165939.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165940.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165941.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165942.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165943.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165944.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165945.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165946.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165947.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165948.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165949.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165950.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165951.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165952.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165953.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165954.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165955.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165956.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165957.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165958.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165959.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165960.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165961.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165962.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165963.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165964.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165965.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165966.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165967.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165968.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165969.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165970.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165971.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165972.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165973.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165974.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165975.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165976.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165977.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165978.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165979.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165980.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165981.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165982.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165983.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165984.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165985.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165986.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165987.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165988.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165989.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165990.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165991.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165992.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165993.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165994.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165995.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165996.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165997.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165998.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n165999.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166000.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166001.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166002.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166003.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166004.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166005.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166006.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166007.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166008.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166009.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166010.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166011.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166012.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166013.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166014.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166015.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166016.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166017.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166018.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166019.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166020.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166021.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166022.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166023.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166024.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166025.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166026.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166027.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166028.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166029.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166030.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166031.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166032.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166033.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166034.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166035.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166036.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166037.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166038.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166039.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166040.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166041.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166042.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166043.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166044.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166045.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166046.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166047.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166048.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166049.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166050.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166051.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166052.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166053.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166054.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166055.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166056.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166057.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166058.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166059.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166060.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166061.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166062.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166063.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166064.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166065.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166066.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166067.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166068.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166069.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166070.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166071.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166072.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166073.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166074.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166075.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166076.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166077.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166078.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166079.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166080.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166081.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166082.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166083.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166084.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166085.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166086.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166087.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166088.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166089.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166090.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166091.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166092.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166093.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166094.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166095.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166096.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166097.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166098.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166099.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166100.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166101.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166102.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166103.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166104.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166105.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166106.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166107.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166108.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166109.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166110.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166111.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166112.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166113.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166114.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166115.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166116.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166117.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166118.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166119.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166120.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166121.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166122.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166123.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166124.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166125.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166126.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166127.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166128.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166129.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166130.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166131.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166132.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166133.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166134.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166135.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166136.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166137.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166138.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166139.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166140.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166141.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166142.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166143.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166144.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166145.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166146.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166147.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166148.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166149.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166150.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166151.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166152.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166153.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166154.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166155.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166156.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166157.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166158.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166159.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166160.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166161.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166162.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166163.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166164.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166165.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166166.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166167.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166168.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166169.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166170.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166171.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166172.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166173.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166174.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166175.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166176.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166177.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166178.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166179.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166180.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166181.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166182.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166183.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166184.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166185.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166186.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166187.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166188.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166189.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166190.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166191.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166192.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166193.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166194.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166195.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166196.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166197.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166198.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166199.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166200.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166201.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166202.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166203.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166204.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166205.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166206.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166207.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166208.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166209.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166210.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166211.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166212.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166213.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166214.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166215.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166216.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166217.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166218.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166219.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166220.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166221.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166222.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166223.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166224.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166225.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166226.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166227.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166228.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166229.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166230.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166231.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166232.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166233.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166234.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166235.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166236.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166237.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166238.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166239.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166240.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166241.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166242.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166243.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166244.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166245.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166246.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166247.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166248.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166249.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166250.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166251.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166252.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166253.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166254.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166255.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166256.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166257.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166258.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166259.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166260.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166261.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166262.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166263.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166264.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166265.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166266.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166267.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166268.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166269.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166270.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166271.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166272.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166273.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166274.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166275.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166276.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166277.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166278.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166279.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166280.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166281.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166282.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166283.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166284.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166285.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166286.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166287.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166288.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166289.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166290.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166291.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166292.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166293.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166294.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166295.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166296.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166297.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166298.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166299.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166300.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166301.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166302.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166303.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166304.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166305.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166306.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166307.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166308.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166309.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166310.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166311.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166312.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166313.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166314.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166315.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166316.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166317.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166318.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166319.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166320.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166321.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166322.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166323.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166324.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166325.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166326.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166327.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166328.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166329.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166330.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166331.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166332.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166333.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166334.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166335.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166336.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166337.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166338.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166339.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166340.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166341.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166342.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166343.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166344.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166345.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166346.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166347.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166348.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166349.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166350.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166351.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166352.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166353.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166354.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166355.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166356.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166357.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166358.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166359.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166360.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166361.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166362.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166363.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166364.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166365.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166366.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166367.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166368.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166369.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166370.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166371.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166372.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166373.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166374.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166375.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166376.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166377.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166378.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166379.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166380.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166381.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166382.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166383.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166384.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166385.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166386.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166387.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166388.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166389.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166390.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166391.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166392.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166393.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166394.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166395.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166396.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166397.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166398.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166399.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166400.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166401.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166402.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166403.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166404.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166405.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166406.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166407.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166408.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166409.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166410.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166411.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166412.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166413.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166414.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166415.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166416.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166417.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166418.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166419.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166420.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166421.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166422.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166423.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166424.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166425.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166426.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166427.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166428.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166429.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166430.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166431.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166432.jpeg
#   inflating: /content/low-resolution/7449-n000128-teddy/n166433.jpeg
# ...
#   inflating: /content/low-resolution/806-n000129-papillon/n170540.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170541.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170542.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170543.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170544.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170545.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170546.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170547.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170548.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170549.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170550.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170551.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170552.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170553.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170554.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170555.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170556.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170557.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170558.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170559.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170560.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170561.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170562.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170563.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170564.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170565.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170566.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170567.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170568.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170569.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170570.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170571.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170572.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170573.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170574.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170575.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170576.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170577.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170578.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170579.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170580.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170581.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170582.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170583.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170584.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170585.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170586.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170587.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170588.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170589.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170590.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170591.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170592.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170593.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170594.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170595.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170596.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170597.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170598.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170599.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170600.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170601.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170602.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170603.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170604.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170605.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170606.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170607.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170608.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170609.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170610.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170611.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170612.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170613.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170614.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170615.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170616.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170618.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170619.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170620.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170621.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170622.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170623.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170624.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170625.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170626.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170627.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170628.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170629.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170630.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170631.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170632.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170633.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170634.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170635.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170636.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170637.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170638.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170639.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170640.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170641.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170642.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170643.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170644.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170645.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170646.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170647.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170648.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170649.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170650.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170651.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170652.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170653.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170654.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170655.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170656.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170657.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170658.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170659.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170660.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170661.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170662.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170663.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170664.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170665.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170666.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170667.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170668.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170669.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170670.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170671.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170672.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170673.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170674.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170675.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170676.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170677.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170678.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170679.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170680.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170681.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170682.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170683.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170684.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170685.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170686.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170687.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170688.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170689.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170690.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170691.jpg
#   inflating: /content/low-resolution/806-n000129-papillon/n170692.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170693.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170694.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170695.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170696.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170697.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170698.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170699.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170700.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170701.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170702.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170703.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170704.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170705.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170706.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170707.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170708.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170709.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170710.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170711.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170712.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170713.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170714.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170715.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170716.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170717.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170718.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170719.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170720.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170721.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170722.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170723.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170724.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170725.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170726.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170727.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170728.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170730.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170731.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170732.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170733.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170734.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170735.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170736.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170737.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170738.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170739.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170740.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170741.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170742.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170743.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170744.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170745.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170746.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170747.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170748.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170749.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170750.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170751.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170752.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170753.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170754.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170755.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170756.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170757.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170758.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170759.jpeg
#   inflating: /content/low-resolution/806-n000129-papillon/n170760.jpeg
#   inflating: /content/low-resolution/~$directoryfilecount.xlsx

# %%
# !unzip "/content/drive/MyDrive/CSCE5218/Dog_Breed_classification/Dog_Breed_dataset/Tshihua/TrainValSplit.zip" -d "/content/"
# Out:
# Archive:  /content/drive/MyDrive/CSCE5218/Dog_Breed_classification/Dog_Breed_dataset/Tshihua/TrainValSplit.zip
#    creating: /content/TrainAndValList/
#   inflating: /content/TrainAndValList/train.lst
#   inflating: /content/TrainAndValList/validation.lst

# %% [markdown]
# ## Split dataset to Train/Test sets

# %%
import argparse
import os
import shutil
import logging
import sys
import glob
from typing import Dict, Any, Set

def split_train_test(images_dir: str, output_dir: str, lst_path: str):
    with open(lst_path, "r") as f:
        lst: Set[str] = set([os.path.basename(line.strip()) for line in f.readlines()])

    for image_name in lst:
        image_path: str = glob.glob(os.path.join(images_dir, "*", image_name), recursive=True)[0]
        class_name: str = os.path.basename(os.path.dirname(image_path))

        dest_dir: str = os.path.join(output_dir, class_name)
        os.makedirs(dest_dir, exist_ok=True)

        logging.info(f"Copying {image_path} to {dest_dir}")
        shutil.copy(image_path, dest_dir)

# %%
TSINGHUA_DOGS_ROOT_DIR = "/content/drive/MyDrive/CSCE5218/Dog_Breed_classification"
content_root = "/content"
# images_dir: str = os.path.join(TSINGHUA_DOGS_ROOT_DIR, "low-resolution")
images_dir: str = os.path.join(content_root, "low-resolution")
train_lst_path: str = os.path.join(content_root, "TrainAndValList", "train.lst")
test_lst_path: str = os.path.join(content_root, "TrainAndValList", "validation.lst")

# %%
## Only run this once if putting data in shared folder on ggdrive

# #Prepare train set
# train_dir: str = os.path.join(TSINGHUA_DOGS_ROOT_DIR, "train")
# os.makedirs(train_dir, exist_ok=True)
# split_train_test(images_dir, output_dir=train_dir, lst_path=train_lst_path)

# #Prepare validation set
# test_dir: str = os.path.join(TSINGHUA_DOGS_ROOT_DIR, "test")
# os.makedirs(test_dir, exist_ok=True)
# split_train_test(images_dir, output_dir=test_dir, lst_path=test_lst_path)

# %%
##If putting data in temporary runtime directory, need to rerun this every time

##Prepare train set
train_dir: str = os.path.join(content_root, "train")
os.makedirs(train_dir, exist_ok=True)
split_train_test(images_dir, output_dir=train_dir, lst_path=train_lst_path)

##Prepare test set
test_dir: str = os.path.join(content_root, "test")
os.makedirs(test_dir, exist_ok=True)
split_train_test(images_dir, output_dir=test_dir, lst_path=test_lst_path)

# %% [markdown]
# # **Defining Neural Network**

# %% [markdown]
# ## Inception-Resnet (Inception Net with Residual connections)

# %% [markdown]
# ### An Inception-Resnet implementation without a pretrained model, following as closely as possible the Inception-Resnet-v2 design in the original paper that introduced it -- "Inception-v4, Inception-ResNet and the impact of residual connections on learning," by C. Szegedy and his team at Google, 2016.

# %%
from __future__ import print_function, division, absolute_import
import torch
import torch.nn as nn
import torch.utils.model_zoo as model_zoo
import os
import sys



class BasicConv2d(nn.Module):

    def __init__(self, in_planes, out_planes, kernel_size, stride, padding=0):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Conv2d(in_planes, out_planes, kernel_size=kernel_size, stride=stride, padding=padding, bias=False) # verify bias=false
        self.bn = nn.BatchNorm2d(out_planes, eps=0.001, momentum=0.1, affine=True)  
        ##param 'eps' uses the value found in tensorflow, which is used for implementation of IRN in original paper
        ##param 'momentum' uses default pytorch value

        self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)

        return x



class BlockStem(nn.Module):
    ##The Stem of the Inception-Resnet v2
    ##There are 2 versions for it, 
    ##The 1st one, as in the original paper, uses the Stem of Inception v4
    ##The 2nd one uses the Stem of Inception-Resnet v1 adds an extra Stem-to-A block
    def __init__(self):
        super(BlockStem, self).__init__()
        self.conv_1 = BasicConv2d(3, 32, kernel_size=3, stride=2)
        self.conv_2 = BasicConv2d(32, 32, kernel_size=3, stride=1)
        self.conv_3 = BasicConv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.maxpool_4 = nn.MaxPool2d(3, stride=2)
        self.conv_4 = BasicConv2d(64, 96, kernel_size=3, stride=2)

        self.branch_5_0 = nn.Sequential(
            BasicConv2d(160, 64, kernel_size=1, stride=1),
            BasicConv2d(64, 96, kernel_size=3, stride=1)
            )

        self.branch_5_1 = nn.Sequential(
            BasicConv2d(160, 64, kernel_size=1, stride=1),
            BasicConv2d(64, 64, kernel_size=(1,7), stride=1, padding=(0,3)),
            BasicConv2d(64, 64, kernel_size=(7,1), stride=1, padding=(3,0)),
            BasicConv2d(64, 96, kernel_size=(3,3), stride=1)
            )
        
        self.conv_6 = BasicConv2d(192, 192, kernel_size=3, stride=2)
        self.maxpool_6 = nn.MaxPool2d(3, stride=2)


    def forward(self, x):
        x = self.conv_1(x) # size: 3->32
        x = self.conv_2(x) # size: 32->32
        x = self.conv_3(x) # size: 32->64

        x0 = self.maxpool_4(x) # size: 64->64
        x1 = self.conv_4(x) # size: 64->96
        out_4 = torch.cat((x0, x1), 1) # size: 64+96=160

        x0 = self.branch_5_0(out_4) # size: 160->96
        x1 = self.branch_5_1(out_4) # size: 160->96
        out_5 = torch.cat((x0, x1), 1) # size: 96+96=192

        x0 = self.conv_6(out_5) # size: 192->192
        x1 = self.maxpool_6(out_5) # size: 192->192
        out_6 = torch.cat((x0, x1), 1) # size: 192+192=384

        return out_6 # size: 384



class BlockSToA(nn.Module):
    ##Block between the Stem and Inception-Resnet-A
    ##Used for the Stem of IRNv1 to build the 2nd ver of Stem for IRNv2
    def __init__(self):
        super(BlockSToA, self).__init__()

        self.branch0 = BasicConv2d(192, 96, kernel_size=1, stride=1)

        self.branch1 = nn.Sequential(
            BasicConv2d(192, 48, kernel_size=1, stride=1),
            BasicConv2d(48, 96, kernel_size=5, stride=1, padding=2)
        )

        self.branch2 = nn.Sequential(
            BasicConv2d(192, 64, kernel_size=1, stride=1),
            BasicConv2d(64, 96, kernel_size=3, stride=1, padding=1),
            BasicConv2d(96, 96, kernel_size=3, stride=1, padding=1)
        )

        self.branch3 = nn.Sequential(
            nn.AvgPool2d(3, stride=1, padding=1, count_include_pad=False),
            BasicConv2d(192, 96, kernel_size=1, stride=1)
        )

    def forward(self, x):
        x0 = self.branch0(x) # size: 192->96
        x1 = self.branch1(x) # size: 192->96
        x2 = self.branch2(x) # size: 192->96
        x3 = self.branch3(x) # size: 192->96
        out = torch.cat((x0, x1, x2, x3), 1) # size: 96+96+96+96=384

        return out



class BlockStemV2(nn.Module):
    ##The Stem of the Inception-Resnet v2
    ##There are 2 versions for it, 
    ##The 1st one, as in the original paper, uses the Stem of Inception v4
    ##The 2nd one uses the Stem of Inception-Resnet v1 adds an extra Stem-to-A block
    def __init__(self):
        super(BlockStemV2, self).__init__()
        self.conv_1 = BasicConv2d(3, 32, kernel_size=3, stride=2)
        self.conv_2 = BasicConv2d(32, 32, kernel_size=3, stride=1)
        self.conv_3 = BasicConv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.maxpool_4 = nn.MaxPool2d(3, stride=2)
        self.conv_5 = BasicConv2d(64, 80, kernel_size=1, stride=1)
        self.conv_6 = BasicConv2d(80, 192, kernel_size=3, stride=1)
        self.maxpool_7 = nn.MaxPool2d(3, stride=2)
        self.block_sta = BlockSToA()


    def forward(self, x):
        x = self.conv_1(x) # size: 3->32
        x = self.conv_2(x) # size: 32->32
        x = self.conv_3(x) # size: 32->64
        x = self.maxpool_4(x) # size: 64->64
        x = self.conv_5(x) # size: 64->80
        x = self.conv_6(x) # size: 80->192
        x = self.maxpool_7(x) # size: 192->192
        x = self.block_sta(x) # size: 192->384

        return x # size: 384



class BlockA(nn.Module):
    ##Inception-Resnet-A: 35x35 grid
    def __init__(self, scale=1.0):
        super(BlockA, self).__init__()

        self.scale = scale

        self.branch0 = BasicConv2d(384, 32, kernel_size=1, stride=1)

        self.branch1 = nn.Sequential(
            BasicConv2d(384, 32, kernel_size=1, stride=1),
            BasicConv2d(32, 32, kernel_size=3, stride=1, padding=1)
        )

        self.branch2 = nn.Sequential(
            BasicConv2d(384, 32, kernel_size=1, stride=1),
            BasicConv2d(32, 48, kernel_size=3, stride=1, padding=1),
            BasicConv2d(48, 64, kernel_size=3, stride=1, padding=1)
        )

        self.conv2d = nn.Conv2d(128, 384, kernel_size=1, stride=1)
        self.relu = nn.ReLU(inplace=False)


    def forward(self, x):
        x0 = self.branch0(x) # size: 384->32
        x1 = self.branch1(x) # size: 384->32
        x2 = self.branch2(x) # size: 384->64
        out = torch.cat((x0, x1, x2), 1) # size: 32+32+64=128
        out = self.conv2d(out) # size: 128->384
        out = out * self.scale + x # size: 384->384
        out = self.relu(out) # size: 384->384

        return out # size: 384



class BlockRA(nn.Module):
    ##Reduction-A: 35x35 -> 17x17
    def __init__(self):
        super(BlockRA, self).__init__()

        self.branch0 = nn.MaxPool2d(3, stride=2)

        self.branch1 = BasicConv2d(384, 384, kernel_size=3, stride=2)

        self.branch2 = nn.Sequential(
            BasicConv2d(384, 256, kernel_size=1, stride=1),
            BasicConv2d(256, 256, kernel_size=3, stride=1, padding=1),
            BasicConv2d(256, 384, kernel_size=3, stride=2)
        )


    def forward(self, x):
        x0 = self.branch0(x) # size: 384->384
        x1 = self.branch1(x) # size: 384->384
        x2 = self.branch2(x) # size: 384->384
        out = torch.cat((x0, x1, x2), 1) # size: 384+384+384=1152

        return out # size:1152



class BlockB(nn.Module):
    ##Inception-Resnet-B: 17x17 grid
    def __init__(self, scale=1.0):
        super(BlockB, self).__init__()

        self.scale = scale

        self.branch0 = BasicConv2d(1152, 192, kernel_size=1, stride=1)

        self.branch1 = nn.Sequential(
            BasicConv2d(1152, 128, kernel_size=1, stride=1),
            BasicConv2d(128, 160, kernel_size=(1,7), stride=1, padding=(0,3)),
            BasicConv2d(160, 192, kernel_size=(7,1), stride=1, padding=(3,0))
        )

        self.conv2d = nn.Conv2d(384, 1152, kernel_size=1, stride=1)
        self.relu = nn.ReLU(inplace=False)


    def forward(self, x):
        x0 = self.branch0(x) # size: 1152->192
        x1 = self.branch1(x) # size: 1152->192
        out = torch.cat((x0, x1), 1) # size: 192+192=384
        out = self.conv2d(out) # size: 384->1152
        out = out * self.scale + x # size: 1152->1152
        out = self.relu(out) # size: 1152->1152

        return out # size: 1152



class BlockRB(nn.Module):
    ##Reduction-B: 17x17 -> 8x8
    def __init__(self):
        super(BlockRB, self).__init__()

        self.branch0 = nn.MaxPool2d(3, stride=2)

        self.branch1 = nn.Sequential(
            BasicConv2d(1152, 256, kernel_size=1, stride=1),
            BasicConv2d(256, 384, kernel_size=3, stride=2)
        )

        self.branch2 = nn.Sequential(
            BasicConv2d(1152, 256, kernel_size=1, stride=1),
            BasicConv2d(256, 288, kernel_size=3, stride=2)
        )

        self.branch3 = nn.Sequential(
            BasicConv2d(1152, 256, kernel_size=1, stride=1),
            BasicConv2d(256, 288, kernel_size=3, stride=1, padding=1),
            BasicConv2d(288, 320, kernel_size=3, stride=2)
        )

        
    def forward(self, x):
        x0 = self.branch0(x) # size: 1152->1152
        x1 = self.branch1(x) # size: 1152->384
        x2 = self.branch2(x) # size: 1152->288
        x3 = self.branch3(x) # size: 1152->320
        out = torch.cat((x0, x1, x2, x3), 1) # size: 1152+384+288+320=2144

        return out # size: 2144



class BlockC(nn.Module):
    ##Inception-Resnet-C: 8x8 grid
    def __init__(self, scale=1.0, noReLU=False):
        super(BlockC, self).__init__()

        self.scale = scale
        self.noReLU = noReLU

        self.branch0 = BasicConv2d(2144, 192, kernel_size=1, stride=1)

        self.branch1 = nn.Sequential(
            BasicConv2d(2144, 192, kernel_size=1, stride=1),
            BasicConv2d(192, 224, kernel_size=(1,3), stride=1, padding=(0,1)),
            BasicConv2d(224, 256, kernel_size=(3,1), stride=1, padding=(1,0))
        )

        self.conv2d = nn.Conv2d(448, 2144, kernel_size=1, stride=1)
        if not self.noReLU:
            self.relu = nn.ReLU(inplace=False)


    def forward(self, x):
        x0 = self.branch0(x) # size: 2144->192
        x1 = self.branch1(x) # size: 2144->256
        out = torch.cat((x0, x1), 1) # size: 192+256=448
        out = self.conv2d(out) # size: 448->2144
        out = out * self.scale + x # size: 2144->2144
        if not self.noReLU:
            out = self.relu(out) # size: 2144->2144

        return out # size: 2144



class InceptionResNet(nn.Module):
    ##Inception-Resnet version 2
    def __init__(self, num_classes=1000):
        super(InceptionResNet, self).__init__()
        # Special attributs
        self.input_space = "RGB"
        self.input_size = (299, 299, 3)
        self.mean = [0.5, 0.5, 0.5]
        self.std = [0.5, 0.5, 0.5]


        ##Modules
        ##The Stem block
        self.block_stem = BlockStem()

        ##Inception-Resnet-A x10
        ##Note: activation scaling is required for stability, as explained in the original paper
        ##Scale is arbitrarily chosen between 0.1--0.3
        self.repeat_a = nn.Sequential(
            BlockA(scale=0.22),
            BlockA(scale=0.22),
            BlockA(scale=0.22),
            BlockA(scale=0.22),
            BlockA(scale=0.22),
            BlockA(scale=0.22),
            BlockA(scale=0.22),
            BlockA(scale=0.22),
            BlockA(scale=0.22),
            BlockA(scale=0.22)
        )

        ##Reduction-A
        self.block_ra = BlockRA()

        ##Inception-Resnet-B x20
        self.repeat_b = nn.Sequential(
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15),
            BlockB(scale=0.15)
        )

        ##Reduction-B
        self.block_rb = BlockRB()

        ##Inception-Resnet-C x9
        self.repeat_c = nn.Sequential(
            BlockC(scale=0.22),
            BlockC(scale=0.22),
            BlockC(scale=0.22),
            BlockC(scale=0.22),
            BlockC(scale=0.22),
            BlockC(scale=0.22),
            BlockC(scale=0.22),
            BlockC(scale=0.22),
            BlockC(scale=0.22)
        )
        ##last BlockC without ReLU, 
        ##and, instead, using conv2d as activation
        self.last_blockC = BlockC(scale=0.22, noReLU=True)
        self.blockC_conv2d = BasicConv2d(2144, 2144, kernel_size=1, stride=1)

        ##average pooling and dropout
        self.last_avgpool = nn.AvgPool2d(8, count_include_pad=False)
        self.last_dropout = nn.Dropout(p=0.2)

        ##last linear activation, i.e., the actual classifier
        self.linear_cls = nn.Linear(2144, num_classes)


    def features(self, input):
        x = self.block_stem(input) # size: 3->384

        x = self.repeat_a(x) # size: 384->384
        x = self.block_ra(x) # size: 384->1152

        x = self.repeat_b(x) # size: 1152->1152
        x = self.block_rb(x) # size: 1152->2144
        x = self.repeat_c(x) # size: 2144->2144

        x = self.last_blockC(x) # size: 2144->2144
        x = self.blockC_conv2d(x) # size: 2144->2144

        return x # size: 2144


    def logits(self, features):
        x = self.last_avgpool(features) # size: 2144->2144
        x = self.last_dropout(x) # size: 2144->2144
        x = x.view(x.size(0), -1) # size: 2144->2144, flatten to 2 dimensions
        x = self.linear_cls(x) # size: 2144->number of classes
        
        return x # size: number of classes


    def forward(self, input):
        x = self.features(input) # size: 3->2144
        x = self.logits(x) # size: 2144->number of classes

        return x # size: number of classes

# %% [markdown]
# # **Define Training Function & Utilities**

# %% [markdown]
# ## Utilities Methods

# %%
import numpy as np
import random
import torch
import torch.nn.functional as F
import torchvision
from torchvision import transforms, models
from torch.autograd import Variable



def cosine_anneal_schedule(t, nb_epoch, lr):
    cos_inner = np.pi * (t % (nb_epoch))  # t - 1 is used when t has 1-based indexing.
    cos_inner /= (nb_epoch)
    cos_out = np.cos(cos_inner) + 1

    return float(lr / 2 * cos_out)


def build_model(require_grad=True, num_classes=0):
    print("==> Building model: " + "Inception-Resnet v2" + "..")
    if num_classes:
      nnet = InceptionResNet(num_classes)  
    else:
      nnet = InceptionResNet() ## default IRNet: 1000 classes

    for param in nnet.parameters():
      param.requires_grad = require_grad
    print("==>Completed building model" + "Inception-Resnet v2" + "!")

    return nnet


def model_info(model):  # Plots a line-by-line description of a PyTorch model
    n_p = sum(x.numel() for x in model.parameters())  # number parameters
    n_g = sum(x.numel() for x in model.parameters() if x.requires_grad)  # number gradients
    print('\n%5s %50s %9s %12s %20s %12s %12s' % ('layer', 'name', 'gradient', 'parameters', 'shape', 'mu', 'sigma'))
    for i, (name, p) in enumerate(model.named_parameters()):
        name = name.replace('module_list.', '')
        print('%5g %50s %9s %12g %20s %12.3g %12.3g' % (
            i, name, p.requires_grad, p.numel(), list(p.shape), p.mean(), p.std()))
    print('Model Summary: %g layers, %g parameters, %g gradients\n' % (i + 1, n_p, n_g))


def test(net, criterion, batch_size, testloader=None):
    net.eval()
    use_cuda = torch.cuda.is_available()
    test_loss = 0
    correct = 0
    correct_com = 0
    total = 0
    idx = 0
    device = torch.device("cuda:0")

    for batch_idx, (inputs, targets) in enumerate(testloader):
        idx = batch_idx
        if use_cuda: #gpu
            inputs, targets = inputs.to(device), targets.to(device) 
        inputs, targets = Variable(inputs, volatile=True), Variable(targets) #cpu

        output_p = net(inputs)
        loss = criterion(output_p, targets)

        test_loss += loss.item()
        _, predicted = torch.max(output_p.data, 1)

        total += targets.size(0)
        correct += predicted.eq(targets.data).cpu().sum()

        if batch_idx % 50 == 0:
            print('Step: %d | Loss: %.3f | Acc: %.3f%% (%d/%d) \n' % 
                  (batch_idx, 
                   test_loss / (batch_idx + 1), 
                   100. * float(correct) / total, 
                   correct, 
                   total
                  )
            )

    test_acc = 100. * float(correct) / total
    test_loss = test_loss / (idx + 1)

    return test_acc, test_loss

# %% [markdown]
# ## Training Function

# %%
from __future__ import print_function
import os
from PIL import Image

import logging
import random
import torch
import torch.optim as optim
import torch.backends.cudnn as cudnn



def train(nb_epoch, batch_size, store_name, resume=False, start_epoch=0, model_path=None, trainloader=None, testloader=None, batch_size_test=3, in_net=None):
    # setup output
    exp_dir = store_name
    try:
        os.stat(exp_dir)
    except:
        os.makedirs(exp_dir)

    use_cuda = torch.cuda.is_available()
    print("GPU is available: ", use_cuda)


    # Model
    if in_net:
        net = in_net
    else:
        net = build_model(num_classes=130) ##dogs breeds dataset has 130 classes

    if resume:
        # if in_net:
        #     if in_net.linear_cls.bias.size()[0] < 1000:
        #         net = build_model()
        #         net.load_state_dict(torch.load(model_path))
        #         linear_in_feature = in_net.linear_cls.weight.size()[1]
        #         linear_out_feature = in_net.linear_cls.weight.size()[0]
        #         new_linear_cls = nn.Linear(linear_in_feature, linear_out_feature)
        #         new_linear_cls.weight.data = net.linear_cls.weight.data[:linear_out_feature]
        #         new_linear_cls.bias.data = net.linear_cls.bias.data[:linear_out_feature]
        #         net.linear_cls = new_linear_cls
        #     else:
        #         net.load_state_dict(torch.load(model_path))
        # else:
        #     net.load_state_dict(torch.load(model_path))

        # net = torch.load(model_path)
        net.load_state_dict(torch.load(model_path))

    netp = torch.nn.DataParallel(net, device_ids=[0])

    # GPU
    device = torch.device("cuda:0")
    net.to(device)
    # cudnn.benchmark = True
    CELoss = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=0.0002, momentum=0.9, weight_decay=5e-4)
    lrScheduler1 = optim.lr_scheduler.CosineAnnealingLR(optimizer, nb_epoch)

    max_val_acc = 0
    for epoch in range(start_epoch, nb_epoch):
        print('\nEpoch: %d' % epoch)
        net.train()
        train_loss = 0
        correct = 0
        total = 0
        idx = 0
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            idx = batch_idx
            if inputs.shape[0] < batch_size:
                continue
            if use_cuda: #gpu
                inputs, targets = inputs.to(device), targets.to(device)
            inputs, targets = Variable(inputs), Variable(targets) #cpu

            # Step 1
            optimizer.zero_grad()
            output_p = netp(inputs)
            loss = CELoss(output_p, targets) * 1
            loss.backward()
            optimizer.step()

            #  training log
            _, predicted = torch.max(output_p.data, 1)
            total += targets.size(0)
            correct += predicted.eq(targets.data).cpu().sum()
            train_loss += loss.item()

            if batch_idx % 50 == 0:
                print(
                    'Step: %d | Loss: %.5f | Acc: %.3f%% (%d/%d)' % 
                    (batch_idx, 
                     train_loss / (batch_idx + 1), 
                     100. * float(correct) / total, correct, total)
                )
            if batch_idx % 500 == 0:
                ##save model every 500 steps
                net.cpu()
                torch.save(net.state_dict(), store_name + '/model_irnetv2.pth')
                net.to(device)
                
        lrScheduler1.step() # update learning rate after each epoch

        train_acc = 100. * float(correct) / total
        train_loss = train_loss / (idx + 1)
        with open(exp_dir + '/results_train_irnetv2.txt', 'a') as file:
            file.write(
                'Iteration %d | train_acc = %.5f | train_loss = %.5f |\n' % 
                (epoch, 
                 train_acc, 
                 train_loss,
                )
            )

        val_acc, val_loss = test(net, CELoss, batch_size=batch_size_test, testloader=testloader)
        if val_acc >= max_val_acc:
            max_val_acc = val_acc
            net.cpu()
            torch.save(net.state_dict(), store_name + '/model_irnetv2_high.pth')
            torch.save(net.state_dict(), store_name + '/model_irnetv2.pth')
            net.to(device)
            with open(exp_dir + '/results_test_irnetv2_high.txt', 'a') as file_h:
                file_h.write('Iteration %d, test_acc = %.5f, test_loss = %.6f\n' % 
                           (epoch, val_acc, val_loss)
                           )
        else:
            net.cpu()
            torch.save(net.state_dict(), store_name + '/model_irnetv2.pth')
            net.to(device)

        with open(exp_dir + '/results_test_irnetv2.txt', 'a') as file:
            file.write('Iteration %d, test_acc = %.5f, test_loss = %.6f\n' % 
                        (epoch, val_acc, val_loss)
            )

    return net, CELoss

# %% [markdown]
# ## Dataloaders (train/test)

# %%
import torch
import torchvision
from torchvision import transforms, models

##Setting parameters
batchSize_train = 16
batchSize_test = 3

##Transform Data
print("==> Preparing data..")
transform_train = transforms.Compose([
        transforms.Resize((550, 550)),
        transforms.RandomCrop(448, padding=8),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ])

transform_test = transforms.Compose([
        transforms.Resize((550, 550)),
        transforms.CenterCrop(448),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ])
# Out:
# ==> Preparing data..

# %%
# ##Data on shared folder on ggdrive
# rootPath = "/content/drive/MyDrive/CSCE5218/Dog_Breed_classification"

# trainset = torchvision.datasets.ImageFolder(root= rootPath + "/train", transform=transform_train)
# train_loader = torch.utils.data.DataLoader(trainset, batch_size=batchSize_train, shuffle=True, num_workers=4)

# testset = torchvision.datasets.ImageFolder(root= rootPath + "/test", transform=transform_test)
# test_loader = torch.utils.data.DataLoader(testset, batch_size=batchSize_test, shuffle=True, num_workers=4)

# %%
##Alternatively, data on temporary runtime directory
rootPath = "/content"

trainset = torchvision.datasets.ImageFolder(root= rootPath + "/train", transform=transform_train)
train_loader = torch.utils.data.DataLoader(trainset, batch_size=batchSize_train, shuffle=True, num_workers=4)

testset = torchvision.datasets.ImageFolder(root= rootPath + "/test", transform=transform_test)
test_loader = torch.utils.data.DataLoader(testset, batch_size=batchSize_test, shuffle=True, num_workers=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# # **Training Section**

# %% [markdown]
# ## Calling Training Function

# %% [markdown]
# ### \*Clean GPU RAM

# %%
# clean memory in case GPU memory is fragmented
torch.cuda.empty_cache()

# %% [markdown]
# ### Initial training
# \* For first-start. \\
# \* Testing on reserved test set is also done every epoch during training.

# %%
# #Initial train
### *** ARCHIVED ***

# #path to store output model and test statistics
# store_path = '/content/drive/MyDrive/CSCE5218/Dog_Breed_classification/output'

# #temporary store on runtime directory
# store_path = '/content/output'

# #calling training
# trained_net, trained_loss = train(nb_epoch=20,             # number of epoch
#         batch_size=batchSize_train,         # batch size
#         store_name=store_path,     # folder for output
#         resume=False,          # resume training from checkpoint
#         start_epoch=0,         # the start epoch number when you resume the training
#         model_path=None,         # the saved model where you want to resume the training
#         trainloader=train_loader,
#         testloader=test_loader,
#         batch_size_test=batchSize_test
#         )
# Out:
# GPU is available:  True
# ==> Building model: Inception-Resnet v2..
#
# Epoch: 0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Step: 0 | Loss: 6.96978 | Acc: 0.000% (0/16)
# Step: 50 | Loss: 6.51758 | Acc: 7.966% (65/816)
# Step: 100 | Loss: 6.07002 | Acc: 9.282% (150/1616)
# Step: 150 | Loss: 5.72490 | Acc: 10.555% (255/2416)
# Step: 200 | Loss: 5.46603 | Acc: 11.287% (363/3216)
# Step: 250 | Loss: 5.30121 | Acc: 11.753% (472/4016)
# Step: 300 | Loss: 5.17951 | Acc: 12.043% (580/4816)
# Step: 350 | Loss: 5.06535 | Acc: 12.518% (703/5616)
# Step: 400 | Loss: 4.97808 | Acc: 12.609% (809/6416)
# Step: 450 | Loss: 4.91229 | Acc: 12.888% (930/7216)
# Step: 500 | Loss: 4.83161 | Acc: 13.386% (1073/8016)
# Step: 550 | Loss: 4.77936 | Acc: 13.373% (1179/8816)
# Step: 600 | Loss: 4.72989 | Acc: 13.706% (1318/9616)
# Step: 650 | Loss: 4.67309 | Acc: 13.988% (1457/10416)
# Step: 700 | Loss: 4.63492 | Acc: 14.087% (1580/11216)
# Step: 750 | Loss: 4.59517 | Acc: 14.248% (1712/12016)
# Step: 800 | Loss: 4.55770 | Acc: 14.544% (1864/12816)
# Step: 850 | Loss: 4.52923 | Acc: 14.791% (2014/13616)
# Step: 900 | Loss: 4.49821 | Acc: 14.942% (2154/14416)
# Step: 950 | Loss: 4.47494 | Acc: 14.991% (2281/15216)
# Step: 1000 | Loss: 4.44892 | Acc: 15.210% (2436/16016)
# Step: 1050 | Loss: 4.42785 | Acc: 15.313% (2575/16816)
# Step: 1100 | Loss: 4.40500 | Acc: 15.446% (2721/17616)
# Step: 1150 | Loss: 4.38333 | Acc: 15.563% (2866/18416)
# Step: 1200 | Loss: 4.36557 | Acc: 15.674% (3012/19216)
# Step: 1250 | Loss: 4.34582 | Acc: 15.742% (3151/20016)

# %%
# #Initial train

# #path to store output model and test statistics
# store_path = '/content/drive/MyDrive/CSCE5218/Dog_Breed_classification/output'

#temporary store on runtime directory
store_path = '/content/output'

#calling training
trained_net, trained_loss = train(nb_epoch=20,             # number of epoch
        batch_size=batchSize_train,         # batch size
        store_name=store_path,     # folder for output
        resume=False,          # resume training from checkpoint
        start_epoch=0,         # the start epoch number when you resume the training
        model_path=None,         # the saved model where you want to resume the training
        trainloader=train_loader,
        testloader=test_loader,
        batch_size_test=batchSize_test
        )

# %% [markdown]
# ### Resumed training
# \*For interrupted training run

# %%
# # clean memory in case GPU memory is fragmented
# torch.cuda.empty_cache()

# %%
 # # #Resumed train

# # print(store_path)

# # #path to store output model and test statistics
store_path = '/content/drive/MyDrive/CSCE5218/Dog_Breed_classification/output'
# #path to load saved model from last run
modelPath = store_path + "/model_irnetv2.pth"

#temporary store on runtime directory
store_path = '/content/output'

irnet_in = build_model(require_grad=True, num_classes=130)
# irnet_in.load_state_dict(torch.load(modelPath)) # not needed, reload done inside train function

# last epoch from previous run
startEpoch = 0

trained_net, trained_loss = train(nb_epoch=20,             # number of epoch
        batch_size=batchSize_train,         # batch size
        store_name=store_path,     # folder for output
        resume=True,          # resume training from checkpoint
        start_epoch=startEpoch,         # the start epoch number when you resume the training
        model_path=modelPath,         # the saved model where you want to resume the training
        trainloader=train_loader,
        testloader=test_loader,
        batch_size_test=batchSize_test,
        in_net=irnet_in
        )
# Out:
# ==> Building model: Inception-Resnet v2..
# ==>Completed building modelInception-Resnet v2!
# GPU is available:  True
#
# Epoch: 0
# Step: 0 | Loss: 2.38500 | Acc: 37.500% (6/16)
# Step: 50 | Loss: 1.93691 | Acc: 49.142% (401/816)
# Step: 100 | Loss: 1.95115 | Acc: 48.515% (784/1616)
# Step: 150 | Loss: 1.97620 | Acc: 47.144% (1139/2416)
# Step: 200 | Loss: 1.98080 | Acc: 46.859% (1507/3216)
# Step: 250 | Loss: 1.97800 | Acc: 46.713% (1876/4016)
# Step: 300 | Loss: 1.96709 | Acc: 47.093% (2268/4816)
# Step: 350 | Loss: 1.96658 | Acc: 47.133% (2647/5616)
# Step: 400 | Loss: 1.96619 | Acc: 47.257% (3032/6416)
# Step: 450 | Loss: 1.96724 | Acc: 47.187% (3405/7216)
# Step: 500 | Loss: 1.96032 | Acc: 47.517% (3809/8016)
# Step: 550 | Loss: 1.97042 | Acc: 47.289% (4169/8816)
# Step: 600 | Loss: 1.96954 | Acc: 47.411% (4559/9616)
# Step: 650 | Loss: 1.96635 | Acc: 47.437% (4941/10416)
# Step: 700 | Loss: 1.95812 | Acc: 47.575% (5336/11216)
# Step: 750 | Loss: 1.95582 | Acc: 47.570% (5716/12016)
# Step: 800 | Loss: 1.95733 | Acc: 47.620% (6103/12816)
# Step: 850 | Loss: 1.95915 | Acc: 47.657% (6489/13616)
# Step: 900 | Loss: 1.95447 | Acc: 47.829% (6895/14416)
# Step: 950 | Loss: 1.95274 | Acc: 47.812% (7275/15216)
# Step: 1000 | Loss: 1.95575 | Acc: 47.796% (7655/16016)
# Step: 1050 | Loss: 1.95385 | Acc: 47.847% (8046/16816)
# Step: 1100 | Loss: 1.95342 | Acc: 47.820% (8424/17616)
# Step: 1150 | Loss: 1.95551 | Acc: 47.823% (8807/18416)
# Step: 1200 | Loss: 1.95851 | Acc: 47.648% (9156/19216)
# Step: 1250 | Loss: 1.96150 | Acc: 47.612% (9530/20016)
# Step: 1300 | Loss: 1.96624 | Acc: 47.536% (9895/20816)
# Step: 1350 | Loss: 1.96028 | Acc: 47.650% (10300/21616)
# Step: 1400 | Loss: 1.96301 | Acc: 47.587% (10667/22416)
# Step: 1450 | Loss: 1.96609 | Acc: 47.433% (11012/23216)
# Step: 1500 | Loss: 1.96690 | Acc: 47.402% (11384/24016)
# Step: 1550 | Loss: 1.96478 | Acc: 47.542% (11798/24816)
# Step: 1600 | Loss: 1.96730 | Acc: 47.466% (12159/25616)
# Step: 1650 | Loss: 1.96979 | Acc: 47.365% (12512/26416)
# Step: 1700 | Loss: 1.96784 | Acc: 47.384% (12896/27216)
# Step: 1750 | Loss: 1.96646 | Acc: 47.384% (13275/28016)
# Step: 1800 | Loss: 1.96655 | Acc: 47.370% (13650/28816)
# Step: 1850 | Loss: 1.96484 | Acc: 47.414% (14042/29616)
# Step: 1900 | Loss: 1.96510 | Acc: 47.386% (14413/30416)
# Step: 1950 | Loss: 1.96568 | Acc: 47.415% (14801/31216)
# Step: 2000 | Loss: 1.96848 | Acc: 47.326% (15152/32016)
# Step: 2050 | Loss: 1.96984 | Acc: 47.282% (15516/32816)
# Step: 2100 | Loss: 1.97062 | Acc: 47.278% (15893/33616)
# Step: 2150 | Loss: 1.96871 | Acc: 47.359% (16299/34416)
# Step: 2200 | Loss: 1.96875 | Acc: 47.399% (16692/35216)
# Step: 2250 | Loss: 1.96751 | Acc: 47.415% (17077/36016)
# Step: 2300 | Loss: 1.96761 | Acc: 47.422% (17459/36816)
# Step: 2350 | Loss: 1.96915 | Acc: 47.363% (17816/37616)
# Step: 2400 | Loss: 1.96906 | Acc: 47.324% (18180/38416)
# Step: 2450 | Loss: 1.96906 | Acc: 47.315% (18555/39216)
# Step: 2500 | Loss: 1.96917 | Acc: 47.271% (18916/40016)
# Step: 2550 | Loss: 1.96902 | Acc: 47.268% (19293/40816)
# Step: 2600 | Loss: 1.96854 | Acc: 47.282% (19677/41616)
# Step: 2650 | Loss: 1.96936 | Acc: 47.232% (20034/42416)
# Step: 2700 | Loss: 1.96939 | Acc: 47.265% (20426/43216)
# Step: 2750 | Loss: 1.96901 | Acc: 47.315% (20826/44016)
# Step: 2800 | Loss: 1.96742 | Acc: 47.360% (21225/44816)
# Step: 2850 | Loss: 1.96733 | Acc: 47.376% (21611/45616)
# Step: 2900 | Loss: 1.96787 | Acc: 47.344% (21975/46416)
# Step: 2950 | Loss: 1.96804 | Acc: 47.334% (22349/47216)
# Step: 3000 | Loss: 1.96805 | Acc: 47.355% (22738/48016)
# Step: 3050 | Loss: 1.96686 | Acc: 47.417% (23147/48816)
# Step: 3100 | Loss: 1.96678 | Acc: 47.392% (23514/49616)
# Step: 3150 | Loss: 1.96731 | Acc: 47.368% (23881/50416)
# Step: 3200 | Loss: 1.96625 | Acc: 47.415% (24284/51216)
# Step: 3250 | Loss: 1.96478 | Acc: 47.420% (24666/52016)
# Step: 3300 | Loss: 1.96329 | Acc: 47.484% (25079/52816)
# Step: 3350 | Loss: 1.96125 | Acc: 47.562% (25501/53616)
# Step: 3400 | Loss: 1.95903 | Acc: 47.596% (25900/54416)
# Step: 3450 | Loss: 1.95917 | Acc: 47.566% (26264/55216)
# Step: 3500 | Loss: 1.95859 | Acc: 47.585% (26655/56016)
# Step: 3550 | Loss: 1.95806 | Acc: 47.585% (27036/56816)
# Step: 3600 | Loss: 1.95817 | Acc: 47.605% (27428/57616)
# Step: 3650 | Loss: 1.95635 | Acc: 47.653% (27837/58416)
# Step: 3700 | Loss: 1.95689 | Acc: 47.636% (28208/59216)
# Step: 3750 | Loss: 1.95589 | Acc: 47.687% (28620/60016)
# Step: 3800 | Loss: 1.95398 | Acc: 47.723% (29023/60816)
# Step: 3850 | Loss: 1.95380 | Acc: 47.710% (29397/61616)
# Step: 3900 | Loss: 1.95559 | Acc: 47.666% (29751/62416)
# Step: 3950 | Loss: 1.95559 | Acc: 47.668% (30134/63216)
# Step: 4000 | Loss: 1.95509 | Acc: 47.679% (30522/64016)
# Step: 4050 | Loss: 1.95463 | Acc: 47.689% (30910/64816)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# Step: 0 | Loss: 3.703 | Acc: 33.333% (1/3)
#
# Step: 50 | Loss: 2.843 | Acc: 27.451% (42/153)
#
# Step: 100 | Loss: 2.735 | Acc: 30.363% (92/303)
#
# Step: 150 | Loss: 2.722 | Acc: 28.918% (131/453)
#
# Step: 200 | Loss: 2.790 | Acc: 26.866% (162/603)
#
# Step: 250 | Loss: 2.748 | Acc: 27.756% (209/753)
#
# Step: 300 | Loss: 2.749 | Acc: 28.239% (255/903)
#
# Step: 350 | Loss: 2.737 | Acc: 28.110% (296/1053)
#
# Step: 400 | Loss: 2.754 | Acc: 28.180% (339/1203)
#
# Step: 450 | Loss: 2.746 | Acc: 28.677% (388/1353)
#
# Step: 500 | Loss: 2.733 | Acc: 28.876% (434/1503)
#
# Step: 550 | Loss: 2.736 | Acc: 29.220% (483/1653)
#
# Step: 600 | Loss: 2.727 | Acc: 29.118% (525/1803)
#
# Step: 650 | Loss: 2.709 | Acc: 29.135% (569/1953)
#
# Step: 700 | Loss: 2.728 | Acc: 28.768% (605/2103)
#
# Step: 750 | Loss: 2.742 | Acc: 28.362% (639/2253)
#
# Step: 800 | Loss: 2.744 | Acc: 28.381% (682/2403)
#
# Step: 850 | Loss: 2.744 | Acc: 28.320% (723/2553)
#
# Step: 900 | Loss: 2.754 | Acc: 28.265% (764/2703)
#
# Step: 950 | Loss: 2.745 | Acc: 28.391% (810/2853)
#
# Step: 1000 | Loss: 2.756 | Acc: 28.172% (846/3003)
#
# Step: 1050 | Loss: 2.748 | Acc: 28.417% (896/3153)
#
# Step: 1100 | Loss: 2.754 | Acc: 28.368% (937/3303)
#
# Step: 1150 | Loss: 2.759 | Acc: 28.207% (974/3453)
#
# Step: 1200 | Loss: 2.757 | Acc: 28.254% (1018/3603)
#
# Step: 1250 | Loss: 2.760 | Acc: 28.297% (1062/3753)
#
# Step: 1300 | Loss: 2.758 | Acc: 28.440% (1110/3903)
#
# Step: 1350 | Loss: 2.748 | Acc: 28.522% (1156/4053)
#
# Step: 1400 | Loss: 2.756 | Acc: 28.551% (1200/4203)
#
# Step: 1450 | Loss: 2.759 | Acc: 28.417% (1237/4353)
#
# Step: 1500 | Loss: 2.758 | Acc: 28.492% (1283/4503)
#
# Step: 1550 | Loss: 2.759 | Acc: 28.412% (1322/4653)
#
# Step: 1600 | Loss: 2.761 | Acc: 28.232% (1356/4803)
#
# Step: 1650 | Loss: 2.764 | Acc: 28.044% (1389/4953)
#
# Step: 1700 | Loss: 2.765 | Acc: 28.180% (1438/5103)
#
#
# Epoch: 1
# Step: 0 | Loss: 1.86551 | Acc: 62.500% (10/16)
# Step: 50 | Loss: 1.85523 | Acc: 50.980% (416/816)
# Step: 100 | Loss: 1.84365 | Acc: 51.176% (827/1616)
# Step: 150 | Loss: 1.87037 | Acc: 50.331% (1216/2416)
# Step: 200 | Loss: 1.87490 | Acc: 50.404% (1621/3216)
# Step: 250 | Loss: 1.89048 | Acc: 50.398% (2024/4016)
# Step: 300 | Loss: 1.88337 | Acc: 50.706% (2442/4816)
# Step: 350 | Loss: 1.89273 | Acc: 50.392% (2830/5616)
# Step: 400 | Loss: 1.89506 | Acc: 50.296% (3227/6416)
# Step: 450 | Loss: 1.89357 | Acc: 50.291% (3629/7216)
# Step: 500 | Loss: 1.89287 | Acc: 50.237% (4027/8016)
# Step: 550 | Loss: 1.88881 | Acc: 50.238% (4429/8816)
# Step: 600 | Loss: 1.88882 | Acc: 50.218% (4829/9616)
# Step: 650 | Loss: 1.89051 | Acc: 50.230% (5232/10416)
# Step: 700 | Loss: 1.88795 | Acc: 50.214% (5632/11216)
# Step: 750 | Loss: 1.88569 | Acc: 50.183% (6030/12016)
# Step: 800 | Loss: 1.88677 | Acc: 50.133% (6425/12816)
# Step: 850 | Loss: 1.88300 | Acc: 50.176% (6832/13616)
# Step: 900 | Loss: 1.88189 | Acc: 50.146% (7229/14416)
# Step: 950 | Loss: 1.88196 | Acc: 50.131% (7628/15216)
# Step: 1000 | Loss: 1.88118 | Acc: 50.225% (8044/16016)
# Step: 1050 | Loss: 1.87880 | Acc: 50.184% (8439/16816)
# Step: 1100 | Loss: 1.87634 | Acc: 50.193% (8842/17616)
# Step: 1150 | Loss: 1.87843 | Acc: 50.136% (9233/18416)
# Step: 1200 | Loss: 1.88080 | Acc: 50.078% (9623/19216)
# Step: 1250 | Loss: 1.87976 | Acc: 50.125% (10033/20016)
# Step: 1300 | Loss: 1.87916 | Acc: 50.101% (10429/20816)
# Step: 1350 | Loss: 1.87589 | Acc: 50.130% (10836/21616)
# Step: 1400 | Loss: 1.87600 | Acc: 50.174% (11247/22416)
# Step: 1450 | Loss: 1.87878 | Acc: 50.065% (11623/23216)
# Step: 1500 | Loss: 1.87935 | Acc: 49.925% (11990/24016)
# Step: 1550 | Loss: 1.88053 | Acc: 49.883% (12379/24816)
# Step: 1600 | Loss: 1.88071 | Acc: 49.817% (12761/25616)
# Step: 1650 | Loss: 1.88097 | Acc: 49.803% (13156/26416)
# Step: 1700 | Loss: 1.88212 | Acc: 49.695% (13525/27216)
# Step: 1750 | Loss: 1.88302 | Acc: 49.664% (13914/28016)
# Step: 1800 | Loss: 1.88736 | Acc: 49.573% (14285/28816)
# Step: 1850 | Loss: 1.88721 | Acc: 49.615% (14694/29616)
# Step: 1900 | Loss: 1.88789 | Acc: 49.596% (15085/30416)
# Step: 1950 | Loss: 1.88476 | Acc: 49.648% (15498/31216)
# Step: 2000 | Loss: 1.88434 | Acc: 49.713% (15916/32016)
# Step: 2050 | Loss: 1.88387 | Acc: 49.659% (16296/32816)
# Step: 2100 | Loss: 1.88425 | Acc: 49.640% (16687/33616)
# Step: 2150 | Loss: 1.88564 | Acc: 49.616% (17076/34416)
# Step: 2200 | Loss: 1.88605 | Acc: 49.563% (17454/35216)
# Step: 2250 | Loss: 1.88822 | Acc: 49.470% (17817/36016)
# Step: 2300 | Loss: 1.89073 | Acc: 49.381% (18180/36816)
# Step: 2350 | Loss: 1.89266 | Acc: 49.349% (18563/37616)
# Step: 2400 | Loss: 1.89372 | Acc: 49.367% (18965/38416)
# Step: 2450 | Loss: 1.89187 | Acc: 49.385% (19367/39216)
# Step: 2500 | Loss: 1.89366 | Acc: 49.358% (19751/40016)
# Step: 2550 | Loss: 1.89204 | Acc: 49.378% (20154/40816)
# Step: 2600 | Loss: 1.89204 | Acc: 49.390% (20554/41616)
# Step: 2650 | Loss: 1.89150 | Acc: 49.411% (20958/42416)
# Step: 2700 | Loss: 1.89107 | Acc: 49.442% (21367/43216)
# Step: 2750 | Loss: 1.89086 | Acc: 49.432% (21758/44016)
# Step: 2800 | Loss: 1.89205 | Acc: 49.373% (22127/44816)
# Step: 2850 | Loss: 1.89273 | Acc: 49.305% (22491/45616)
# Step: 2900 | Loss: 1.89261 | Acc: 49.308% (22887/46416)
# Step: 2950 | Loss: 1.89250 | Acc: 49.310% (23282/47216)
# Step: 3000 | Loss: 1.89323 | Acc: 49.304% (23674/48016)
# Step: 3050 | Loss: 1.89328 | Acc: 49.299% (24066/48816)
# Step: 3100 | Loss: 1.89306 | Acc: 49.305% (24463/49616)
# Step: 3150 | Loss: 1.89397 | Acc: 49.280% (24845/50416)
# Step: 3200 | Loss: 1.89265 | Acc: 49.305% (25252/51216)
# Step: 3250 | Loss: 1.89236 | Acc: 49.302% (25645/52016)
# Step: 3300 | Loss: 1.89215 | Acc: 49.301% (26039/52816)
# Step: 3350 | Loss: 1.89261 | Acc: 49.284% (26424/53616)
# Step: 3400 | Loss: 1.89228 | Acc: 49.324% (26840/54416)
# Step: 3450 | Loss: 1.89086 | Acc: 49.353% (27251/55216)
# Step: 3500 | Loss: 1.88947 | Acc: 49.404% (27674/56016)
# Step: 3550 | Loss: 1.88990 | Acc: 49.396% (28065/56816)
# Step: 3600 | Loss: 1.88883 | Acc: 49.410% (28468/57616)
# Step: 3650 | Loss: 1.88824 | Acc: 49.397% (28856/58416)
# Step: 3700 | Loss: 1.88773 | Acc: 49.421% (29265/59216)
# Step: 3750 | Loss: 1.88578 | Acc: 49.487% (29700/60016)
# Step: 3800 | Loss: 1.88484 | Acc: 49.507% (30108/60816)
# Step: 3850 | Loss: 1.88484 | Acc: 49.505% (30503/61616)
# Step: 3900 | Loss: 1.88291 | Acc: 49.527% (30913/62416)
# Step: 3950 | Loss: 1.88203 | Acc: 49.549% (31323/63216)
# Step: 4000 | Loss: 1.88269 | Acc: 49.556% (31724/64016)
# Step: 4050 | Loss: 1.88049 | Acc: 49.599% (32148/64816)
# Step: 0 | Loss: 4.071 | Acc: 33.333% (1/3)
#
# Step: 50 | Loss: 2.652 | Acc: 30.719% (47/153)
#
# Step: 100 | Loss: 2.675 | Acc: 30.033% (91/303)
#
# Step: 150 | Loss: 2.746 | Acc: 27.152% (123/453)
#
# Step: 200 | Loss: 2.734 | Acc: 27.363% (165/603)
#
# Step: 250 | Loss: 2.715 | Acc: 28.685% (216/753)
#
# Step: 300 | Loss: 2.728 | Acc: 28.571% (258/903)
#
# Step: 350 | Loss: 2.745 | Acc: 28.775% (303/1053)
#
# Step: 400 | Loss: 2.742 | Acc: 28.678% (345/1203)
#
# Step: 450 | Loss: 2.712 | Acc: 29.638% (401/1353)
#
# Step: 500 | Loss: 2.720 | Acc: 29.208% (439/1503)
#
# Step: 550 | Loss: 2.706 | Acc: 29.341% (485/1653)
#
# Step: 600 | Loss: 2.720 | Acc: 29.340% (529/1803)
#
# Step: 650 | Loss: 2.716 | Acc: 29.647% (579/1953)
#
# Step: 700 | Loss: 2.716 | Acc: 29.482% (620/2103)
#
# Step: 750 | Loss: 2.709 | Acc: 29.738% (670/2253)
#
# Step: 800 | Loss: 2.712 | Acc: 29.505% (709/2403)
#
# Step: 850 | Loss: 2.701 | Acc: 29.769% (760/2553)
#
# Step: 900 | Loss: 2.692 | Acc: 29.708% (803/2703)
#
# Step: 950 | Loss: 2.691 | Acc: 29.828% (851/2853)
#
# Step: 1000 | Loss: 2.697 | Acc: 29.837% (896/3003)
#
# Step: 1050 | Loss: 2.691 | Acc: 30.193% (952/3153)
#
# Step: 1100 | Loss: 2.697 | Acc: 30.064% (993/3303)
#
# Step: 1150 | Loss: 2.686 | Acc: 30.148% (1041/3453)
#
# Step: 1200 | Loss: 2.682 | Acc: 30.114% (1085/3603)
#
# Step: 1250 | Loss: 2.684 | Acc: 30.029% (1127/3753)
#
# Step: 1300 | Loss: 2.680 | Acc: 29.977% (1170/3903)
#
# Step: 1350 | Loss: 2.687 | Acc: 30.002% (1216/4053)
#
# Step: 1400 | Loss: 2.690 | Acc: 29.931% (1258/4203)
#
# Step: 1450 | Loss: 2.692 | Acc: 29.910% (1302/4353)
#
# Step: 1500 | Loss: 2.688 | Acc: 29.913% (1347/4503)
#
# Step: 1550 | Loss: 2.690 | Acc: 29.766% (1385/4653)
#
# Step: 1600 | Loss: 2.688 | Acc: 29.690% (1426/4803)
#
# Step: 1650 | Loss: 2.688 | Acc: 29.598% (1466/4953)
#
# Step: 1700 | Loss: 2.684 | Acc: 29.630% (1512/5103)
#
#
# Epoch: 2
# Step: 0 | Loss: 1.67070 | Acc: 50.000% (8/16)
# Step: 50 | Loss: 1.92278 | Acc: 47.672% (389/816)
# Step: 100 | Loss: 1.86541 | Acc: 48.948% (791/1616)
# Step: 150 | Loss: 1.84458 | Acc: 50.124% (1211/2416)
# Step: 200 | Loss: 1.83599 | Acc: 50.529% (1625/3216)
# Step: 250 | Loss: 1.84901 | Acc: 50.125% (2013/4016)
# Step: 300 | Loss: 1.83167 | Acc: 50.249% (2420/4816)
# Step: 350 | Loss: 1.83235 | Acc: 49.858% (2800/5616)
# Step: 400 | Loss: 1.82154 | Acc: 50.218% (3222/6416)
# Step: 450 | Loss: 1.82230 | Acc: 50.346% (3633/7216)
# Step: 500 | Loss: 1.83591 | Acc: 50.125% (4018/8016)
# Step: 550 | Loss: 1.83631 | Acc: 50.216% (4427/8816)
# Step: 600 | Loss: 1.83672 | Acc: 50.177% (4825/9616)
# Step: 650 | Loss: 1.83247 | Acc: 50.442% (5254/10416)
# Step: 700 | Loss: 1.82915 | Acc: 50.464% (5660/11216)
# Step: 750 | Loss: 1.83881 | Acc: 50.258% (6039/12016)
# Step: 800 | Loss: 1.84389 | Acc: 50.226% (6437/12816)
# Step: 850 | Loss: 1.84660 | Acc: 50.242% (6841/13616)
# Step: 900 | Loss: 1.85171 | Acc: 50.125% (7226/14416)
# Step: 950 | Loss: 1.84386 | Acc: 50.269% (7649/15216)
# Step: 1000 | Loss: 1.84181 | Acc: 50.325% (8060/16016)
# Step: 1050 | Loss: 1.83830 | Acc: 50.404% (8476/16816)
# Step: 1100 | Loss: 1.83623 | Acc: 50.437% (8885/17616)
# Step: 1150 | Loss: 1.83271 | Acc: 50.565% (9312/18416)
# Step: 1200 | Loss: 1.83384 | Acc: 50.494% (9703/19216)
# Step: 1250 | Loss: 1.83189 | Acc: 50.605% (10129/20016)
# Step: 1300 | Loss: 1.82810 | Acc: 50.797% (10574/20816)
# Step: 1350 | Loss: 1.82992 | Acc: 50.773% (10975/21616)
# Step: 1400 | Loss: 1.82858 | Acc: 50.807% (11389/22416)
# Step: 1450 | Loss: 1.82842 | Acc: 50.853% (11806/23216)
# Step: 1500 | Loss: 1.83021 | Acc: 50.795% (12199/24016)
# Step: 1550 | Loss: 1.82787 | Acc: 50.850% (12619/24816)
# Step: 1600 | Loss: 1.82663 | Acc: 50.898% (13038/25616)
# Step: 1650 | Loss: 1.82745 | Acc: 50.867% (13437/26416)
# Step: 1700 | Loss: 1.82563 | Acc: 50.926% (13860/27216)
# Step: 1750 | Loss: 1.82489 | Acc: 51.007% (14290/28016)
# Step: 1800 | Loss: 1.82621 | Acc: 50.979% (14690/28816)
# Step: 1850 | Loss: 1.82635 | Acc: 50.972% (15096/29616)
# Step: 1900 | Loss: 1.82395 | Acc: 50.980% (15506/30416)
# Step: 1950 | Loss: 1.82458 | Acc: 50.996% (15919/31216)
# Step: 2000 | Loss: 1.82580 | Acc: 50.940% (16309/32016)
# Step: 2050 | Loss: 1.82406 | Acc: 50.981% (16730/32816)
# Step: 2100 | Loss: 1.82574 | Acc: 50.943% (17125/33616)
# Step: 2150 | Loss: 1.82491 | Acc: 51.017% (17558/34416)
# Step: 2200 | Loss: 1.82403 | Acc: 51.034% (17972/35216)
# Step: 2250 | Loss: 1.82195 | Acc: 51.058% (18389/36016)
# Step: 2300 | Loss: 1.82053 | Acc: 51.040% (18791/36816)
# Step: 2350 | Loss: 1.81817 | Acc: 51.087% (19217/37616)
# Step: 2400 | Loss: 1.81687 | Acc: 51.140% (19646/38416)
# Step: 2450 | Loss: 1.81607 | Acc: 51.176% (20069/39216)
# Step: 2500 | Loss: 1.81689 | Acc: 51.192% (20485/40016)
# Step: 2550 | Loss: 1.81603 | Acc: 51.220% (20906/40816)
# Step: 2600 | Loss: 1.81549 | Acc: 51.204% (21309/41616)
# Step: 2650 | Loss: 1.81577 | Acc: 51.212% (21722/42416)
# Step: 2700 | Loss: 1.81498 | Acc: 51.268% (22156/43216)
# Step: 2750 | Loss: 1.81446 | Acc: 51.254% (22560/44016)
# Step: 2800 | Loss: 1.81402 | Acc: 51.241% (22964/44816)
# Step: 2850 | Loss: 1.81553 | Acc: 51.186% (23349/45616)
# Step: 2900 | Loss: 1.81638 | Acc: 51.148% (23741/46416)
# Step: 2950 | Loss: 1.81718 | Acc: 51.125% (24139/47216)
# Step: 3000 | Loss: 1.81719 | Acc: 51.141% (24556/48016)
# Step: 3050 | Loss: 1.81604 | Acc: 51.182% (24985/48816)
# Step: 3100 | Loss: 1.81553 | Acc: 51.191% (25399/49616)
# Step: 3150 | Loss: 1.81518 | Acc: 51.174% (25800/50416)
# Step: 3200 | Loss: 1.81444 | Acc: 51.220% (26233/51216)
# Step: 3250 | Loss: 1.81555 | Acc: 51.173% (26618/52016)
# Step: 3300 | Loss: 1.81628 | Acc: 51.176% (27029/52816)
# Step: 3350 | Loss: 1.81611 | Acc: 51.156% (27428/53616)
# Step: 3400 | Loss: 1.81566 | Acc: 51.132% (27824/54416)
# Step: 3450 | Loss: 1.81471 | Acc: 51.141% (28238/55216)
# Step: 3500 | Loss: 1.81413 | Acc: 51.168% (28662/56016)
# Step: 3550 | Loss: 1.81417 | Acc: 51.123% (29046/56816)
# Step: 3600 | Loss: 1.81480 | Acc: 51.073% (29426/57616)
# Step: 3650 | Loss: 1.81469 | Acc: 51.065% (29830/58416)
# Step: 3700 | Loss: 1.81274 | Acc: 51.116% (30269/59216)
# Step: 3750 | Loss: 1.81291 | Acc: 51.136% (30690/60016)
# Step: 3800 | Loss: 1.81237 | Acc: 51.151% (31108/60816)
# Step: 3850 | Loss: 1.81233 | Acc: 51.169% (31528/61616)
# Step: 3900 | Loss: 1.81121 | Acc: 51.187% (31949/62416)
# Step: 3950 | Loss: 1.81235 | Acc: 51.133% (32324/63216)
# Step: 4000 | Loss: 1.81198 | Acc: 51.150% (32744/64016)
# Step: 4050 | Loss: 1.81240 | Acc: 51.142% (33148/64816)
# Step: 0 | Loss: 2.290 | Acc: 33.333% (1/3)
#
# Step: 50 | Loss: 2.757 | Acc: 32.680% (50/153)
#
# Step: 100 | Loss: 2.711 | Acc: 31.683% (96/303)
#
# Step: 150 | Loss: 2.750 | Acc: 30.905% (140/453)
#
# Step: 200 | Loss: 2.807 | Acc: 29.353% (177/603)
#
# Step: 250 | Loss: 2.813 | Acc: 28.287% (213/753)
#
# Step: 300 | Loss: 2.841 | Acc: 28.350% (256/903)
#
# Step: 350 | Loss: 2.826 | Acc: 28.490% (300/1053)
#
# Step: 400 | Loss: 2.826 | Acc: 28.096% (338/1203)
#
# Step: 450 | Loss: 2.813 | Acc: 28.825% (390/1353)
#
# Step: 500 | Loss: 2.804 | Acc: 28.410% (427/1503)
#
# Step: 550 | Loss: 2.794 | Acc: 28.494% (471/1653)
#
# Step: 600 | Loss: 2.802 | Acc: 28.342% (511/1803)
#
# Step: 650 | Loss: 2.791 | Acc: 28.367% (554/1953)
#
# Step: 700 | Loss: 2.803 | Acc: 28.198% (593/2103)
#
# Step: 750 | Loss: 2.802 | Acc: 28.051% (632/2253)
#
# Step: 800 | Loss: 2.813 | Acc: 27.757% (667/2403)
#
# Step: 850 | Loss: 2.811 | Acc: 27.771% (709/2553)
#
# Step: 900 | Loss: 2.807 | Acc: 28.043% (758/2703)
#
# Step: 950 | Loss: 2.803 | Acc: 28.076% (801/2853)
#
# Step: 1000 | Loss: 2.806 | Acc: 28.139% (845/3003)
#
# Step: 1050 | Loss: 2.800 | Acc: 28.259% (891/3153)
#
# Step: 1100 | Loss: 2.800 | Acc: 28.277% (934/3303)
#
# Step: 1150 | Loss: 2.786 | Acc: 28.613% (988/3453)
#
# Step: 1200 | Loss: 2.798 | Acc: 28.560% (1029/3603)
#
# Step: 1250 | Loss: 2.796 | Acc: 28.511% (1070/3753)
#
# Step: 1300 | Loss: 2.789 | Acc: 28.388% (1108/3903)
#
# Step: 1350 | Loss: 2.795 | Acc: 28.078% (1138/4053)
#
# Step: 1400 | Loss: 2.803 | Acc: 27.813% (1169/4203)
#
# Step: 1450 | Loss: 2.804 | Acc: 27.889% (1214/4353)
#
# Step: 1500 | Loss: 2.801 | Acc: 27.981% (1260/4503)
#
# Step: 1550 | Loss: 2.806 | Acc: 27.982% (1302/4653)
#
# Step: 1600 | Loss: 2.807 | Acc: 28.024% (1346/4803)
#
# Step: 1650 | Loss: 2.812 | Acc: 27.922% (1383/4953)
#
# Step: 1700 | Loss: 2.809 | Acc: 27.964% (1427/5103)
#
#
# Epoch: 3
# Step: 0 | Loss: 2.19769 | Acc: 37.500% (6/16)
# Step: 50 | Loss: 1.78682 | Acc: 50.980% (416/816)
# Step: 100 | Loss: 1.78139 | Acc: 51.671% (835/1616)
# Step: 150 | Loss: 1.77635 | Acc: 51.283% (1239/2416)
# Step: 200 | Loss: 1.76460 | Acc: 51.461% (1655/3216)
# Step: 250 | Loss: 1.77259 | Acc: 51.021% (2049/4016)
# Step: 300 | Loss: 1.75548 | Acc: 51.412% (2476/4816)
# Step: 350 | Loss: 1.76810 | Acc: 50.944% (2861/5616)
# Step: 400 | Loss: 1.77377 | Acc: 51.091% (3278/6416)
# Step: 450 | Loss: 1.76716 | Acc: 51.289% (3701/7216)
# Step: 500 | Loss: 1.77047 | Acc: 51.173% (4102/8016)
# Step: 550 | Loss: 1.76806 | Acc: 51.248% (4518/8816)
# Step: 600 | Loss: 1.76921 | Acc: 51.414% (4944/9616)
# Step: 650 | Loss: 1.76658 | Acc: 51.430% (5357/10416)
# Step: 700 | Loss: 1.76262 | Acc: 51.641% (5792/11216)
# Step: 750 | Loss: 1.76027 | Acc: 51.789% (6223/12016)
# Step: 800 | Loss: 1.76239 | Acc: 51.841% (6644/12816)
# Step: 850 | Loss: 1.76105 | Acc: 51.865% (7062/13616)
# Step: 900 | Loss: 1.75989 | Acc: 51.915% (7484/14416)
# Step: 950 | Loss: 1.76494 | Acc: 51.939% (7903/15216)
# Step: 1000 | Loss: 1.76061 | Acc: 52.042% (8335/16016)
# Step: 1050 | Loss: 1.76473 | Acc: 52.010% (8746/16816)
# Step: 1100 | Loss: 1.76541 | Acc: 51.975% (9156/17616)
# Step: 1150 | Loss: 1.76070 | Acc: 52.156% (9605/18416)
# Step: 1200 | Loss: 1.76035 | Acc: 52.206% (10032/19216)
# Step: 1250 | Loss: 1.75729 | Acc: 52.233% (10455/20016)
# Step: 1300 | Loss: 1.75912 | Acc: 52.119% (10849/20816)
# Step: 1350 | Loss: 1.75720 | Acc: 52.188% (11281/21616)
# Step: 1400 | Loss: 1.75893 | Acc: 52.101% (11679/22416)
# Step: 1450 | Loss: 1.75991 | Acc: 52.085% (12092/23216)
# Step: 1500 | Loss: 1.75922 | Acc: 52.132% (12520/24016)
# Step: 1550 | Loss: 1.75465 | Acc: 52.236% (12963/24816)
# Step: 1600 | Loss: 1.75445 | Acc: 52.284% (13393/25616)
# Step: 1650 | Loss: 1.75746 | Acc: 52.222% (13795/26416)
# Step: 1700 | Loss: 1.75857 | Acc: 52.186% (14203/27216)
# Step: 1750 | Loss: 1.75517 | Acc: 52.284% (14648/28016)
# Step: 1800 | Loss: 1.75445 | Acc: 52.294% (15069/28816)
# Step: 1850 | Loss: 1.75252 | Acc: 52.340% (15501/29616)
# Step: 1900 | Loss: 1.75165 | Acc: 52.364% (15927/30416)
# Step: 1950 | Loss: 1.75171 | Acc: 52.329% (16335/31216)
# Step: 2000 | Loss: 1.74819 | Acc: 52.439% (16789/32016)
# Step: 2050 | Loss: 1.74845 | Acc: 52.471% (17219/32816)
# Step: 2100 | Loss: 1.74724 | Acc: 52.543% (17663/33616)
# Step: 2150 | Loss: 1.74687 | Acc: 52.545% (18084/34416)
# Step: 2200 | Loss: 1.74643 | Acc: 52.541% (18503/35216)
# Step: 2250 | Loss: 1.74530 | Acc: 52.599% (18944/36016)
# Step: 2300 | Loss: 1.74649 | Acc: 52.556% (19349/36816)
# Step: 2350 | Loss: 1.74756 | Acc: 52.555% (19769/37616)
# Step: 2400 | Loss: 1.74726 | Acc: 52.569% (20195/38416)
# Step: 2450 | Loss: 1.74620 | Acc: 52.581% (20620/39216)
# Step: 2500 | Loss: 1.74604 | Acc: 52.576% (21039/40016)
# Step: 2550 | Loss: 1.74638 | Acc: 52.577% (21460/40816)
# Step: 2600 | Loss: 1.74690 | Acc: 52.564% (21875/41616)
# Step: 2650 | Loss: 1.74561 | Acc: 52.586% (22305/42416)
# Step: 2700 | Loss: 1.74571 | Acc: 52.594% (22729/43216)
# Step: 2750 | Loss: 1.74695 | Acc: 52.583% (23145/44016)
# Step: 2800 | Loss: 1.74969 | Acc: 52.535% (23544/44816)
# Step: 2850 | Loss: 1.75004 | Acc: 52.506% (23951/45616)
# Step: 2900 | Loss: 1.74901 | Acc: 52.523% (24379/46416)
# Step: 2950 | Loss: 1.74744 | Acc: 52.533% (24804/47216)
# Step: 3000 | Loss: 1.74571 | Acc: 52.564% (25239/48016)
# Step: 3050 | Loss: 1.74533 | Acc: 52.550% (25653/48816)
# Step: 3100 | Loss: 1.74382 | Acc: 52.540% (26068/49616)
# Step: 3150 | Loss: 1.74391 | Acc: 52.563% (26500/50416)
# Step: 3200 | Loss: 1.74507 | Acc: 52.544% (26911/51216)
# Step: 3250 | Loss: 1.74506 | Acc: 52.555% (27337/52016)
# Step: 3300 | Loss: 1.74633 | Acc: 52.512% (27735/52816)
# Step: 3350 | Loss: 1.74573 | Acc: 52.522% (28160/53616)
# Step: 3400 | Loss: 1.74760 | Acc: 52.468% (28551/54416)
# Step: 3450 | Loss: 1.74647 | Acc: 52.521% (29000/55216)
# Step: 3500 | Loss: 1.74687 | Acc: 52.499% (29408/56016)
# Step: 3550 | Loss: 1.74612 | Acc: 52.513% (29836/56816)
# Step: 3600 | Loss: 1.74619 | Acc: 52.501% (30249/57616)
# Step: 3650 | Loss: 1.74525 | Acc: 52.511% (30675/58416)
# Step: 3700 | Loss: 1.74417 | Acc: 52.545% (31115/59216)
# Step: 3750 | Loss: 1.74522 | Acc: 52.526% (31524/60016)
# Step: 3800 | Loss: 1.74442 | Acc: 52.545% (31956/60816)
# Step: 3850 | Loss: 1.74490 | Acc: 52.530% (32367/61616)
# Step: 3900 | Loss: 1.74485 | Acc: 52.541% (32794/62416)
# Step: 3950 | Loss: 1.74472 | Acc: 52.577% (33237/63216)
# Step: 4000 | Loss: 1.74465 | Acc: 52.592% (33667/64016)
# Step: 4050 | Loss: 1.74407 | Acc: 52.610% (34100/64816)
# Step: 0 | Loss: 2.451 | Acc: 33.333% (1/3)
#
# Step: 50 | Loss: 2.574 | Acc: 30.719% (47/153)
#
# Step: 100 | Loss: 2.646 | Acc: 29.703% (90/303)
#
# Step: 150 | Loss: 2.698 | Acc: 28.477% (129/453)
#
# Step: 200 | Loss: 2.707 | Acc: 28.027% (169/603)
#
# Step: 250 | Loss: 2.772 | Acc: 28.021% (211/753)
#
# Step: 300 | Loss: 2.736 | Acc: 28.793% (260/903)
#
# Step: 350 | Loss: 2.700 | Acc: 29.440% (310/1053)
#
# Step: 400 | Loss: 2.695 | Acc: 29.759% (358/1203)
#
# Step: 450 | Loss: 2.687 | Acc: 29.860% (404/1353)
#
# Step: 500 | Loss: 2.669 | Acc: 30.073% (452/1503)
#
# Step: 550 | Loss: 2.666 | Acc: 29.704% (491/1653)
#
# Step: 600 | Loss: 2.653 | Acc: 30.283% (546/1803)
#
# Step: 650 | Loss: 2.643 | Acc: 30.466% (595/1953)
#
# Step: 700 | Loss: 2.644 | Acc: 30.290% (637/2103)
#
# Step: 750 | Loss: 2.651 | Acc: 30.093% (678/2253)
#
# Step: 800 | Loss: 2.652 | Acc: 29.963% (720/2403)
#
# Step: 850 | Loss: 2.642 | Acc: 30.474% (778/2553)
#
# Step: 900 | Loss: 2.637 | Acc: 30.781% (832/2703)
#
# Step: 950 | Loss: 2.648 | Acc: 30.564% (872/2853)
#
# Step: 1000 | Loss: 2.646 | Acc: 30.470% (915/3003)
#
# Step: 1050 | Loss: 2.644 | Acc: 30.479% (961/3153)
#
# Step: 1100 | Loss: 2.636 | Acc: 30.609% (1011/3303)
#
# Step: 1150 | Loss: 2.626 | Acc: 30.843% (1065/3453)
#
# Step: 1200 | Loss: 2.631 | Acc: 30.669% (1105/3603)
#
# Step: 1250 | Loss: 2.628 | Acc: 30.749% (1154/3753)
#
# Step: 1300 | Loss: 2.630 | Acc: 30.746% (1200/3903)
#
# Step: 1350 | Loss: 2.627 | Acc: 30.792% (1248/4053)
#
# Step: 1400 | Loss: 2.628 | Acc: 31.002% (1303/4203)
#
# Step: 1450 | Loss: 2.628 | Acc: 30.875% (1344/4353)
#
# Step: 1500 | Loss: 2.633 | Acc: 30.868% (1390/4503)
#
# Step: 1550 | Loss: 2.633 | Acc: 30.905% (1438/4653)
#
# Step: 1600 | Loss: 2.636 | Acc: 30.793% (1479/4803)
#
# Step: 1650 | Loss: 2.634 | Acc: 30.830% (1527/4953)
#
# Step: 1700 | Loss: 2.630 | Acc: 30.864% (1575/5103)
#
#
# Epoch: 4
# Step: 0 | Loss: 1.75985 | Acc: 62.500% (10/16)
# Step: 50 | Loss: 1.63301 | Acc: 56.005% (457/816)
# Step: 100 | Loss: 1.64082 | Acc: 54.950% (888/1616)
# Step: 150 | Loss: 1.67247 | Acc: 54.056% (1306/2416)
# Step: 200 | Loss: 1.65451 | Acc: 54.633% (1757/3216)
# Step: 250 | Loss: 1.67152 | Acc: 54.158% (2175/4016)
# Step: 300 | Loss: 1.68141 | Acc: 53.883% (2595/4816)
# Step: 350 | Loss: 1.67034 | Acc: 54.149% (3041/5616)
# Step: 400 | Loss: 1.67175 | Acc: 53.990% (3464/6416)
# Step: 450 | Loss: 1.66144 | Acc: 54.254% (3915/7216)
# Step: 500 | Loss: 1.66787 | Acc: 54.042% (4332/8016)
# Step: 550 | Loss: 1.66712 | Acc: 54.140% (4773/8816)
# Step: 600 | Loss: 1.65793 | Acc: 54.274% (5219/9616)
# Step: 650 | Loss: 1.65872 | Acc: 54.397% (5666/10416)
# Step: 700 | Loss: 1.65285 | Acc: 54.565% (6120/11216)
# Step: 750 | Loss: 1.65080 | Acc: 54.611% (6562/12016)
# Step: 800 | Loss: 1.64643 | Acc: 54.627% (7001/12816)
# Step: 850 | Loss: 1.64969 | Acc: 54.465% (7416/13616)
# Step: 900 | Loss: 1.65557 | Acc: 54.315% (7830/14416)
# Step: 950 | Loss: 1.65743 | Acc: 54.232% (8252/15216)
# Step: 1000 | Loss: 1.65951 | Acc: 54.208% (8682/16016)
# Step: 1050 | Loss: 1.65615 | Acc: 54.401% (9148/16816)
# Step: 1100 | Loss: 1.65778 | Acc: 54.371% (9578/17616)
# Step: 1150 | Loss: 1.65740 | Acc: 54.333% (10006/18416)
# Step: 1200 | Loss: 1.66133 | Acc: 54.236% (10422/19216)
# Step: 1250 | Loss: 1.66613 | Acc: 54.102% (10829/20016)
# Step: 1300 | Loss: 1.66764 | Acc: 54.103% (11262/20816)
# Step: 1350 | Loss: 1.66705 | Acc: 54.187% (11713/21616)
# Step: 1400 | Loss: 1.66631 | Acc: 54.211% (12152/22416)
# Step: 1450 | Loss: 1.66579 | Acc: 54.182% (12579/23216)
# Step: 1500 | Loss: 1.66756 | Acc: 54.168% (13009/24016)
# Step: 1550 | Loss: 1.67123 | Acc: 54.074% (13419/24816)
# Step: 1600 | Loss: 1.67233 | Acc: 54.009% (13835/25616)
# Step: 1650 | Loss: 1.67430 | Acc: 54.005% (14266/26416)
# Step: 1700 | Loss: 1.67453 | Acc: 54.016% (14701/27216)
# Step: 1750 | Loss: 1.67441 | Acc: 54.026% (15136/28016)
# Step: 1800 | Loss: 1.67457 | Acc: 54.005% (15562/28816)
# Step: 1850 | Loss: 1.67507 | Acc: 53.937% (15974/29616)
# Step: 1900 | Loss: 1.67646 | Acc: 53.935% (16405/30416)
# Step: 1950 | Loss: 1.67596 | Acc: 53.921% (16832/31216)
# Step: 2000 | Loss: 1.68005 | Acc: 53.848% (17240/32016)
# Step: 2050 | Loss: 1.68093 | Acc: 53.858% (17674/32816)
# Step: 2100 | Loss: 1.68097 | Acc: 53.894% (18117/33616)
# Step: 2150 | Loss: 1.68085 | Acc: 53.896% (18549/34416)
# Step: 2200 | Loss: 1.67803 | Acc: 53.944% (18997/35216)
# Step: 2250 | Loss: 1.67940 | Acc: 53.937% (19426/36016)
# Step: 2300 | Loss: 1.68195 | Acc: 53.862% (19830/36816)
# Step: 2350 | Loss: 1.67987 | Acc: 53.911% (20279/37616)
# Step: 2400 | Loss: 1.68053 | Acc: 53.847% (20686/38416)
# Step: 2450 | Loss: 1.68075 | Acc: 53.810% (21102/39216)
# Step: 2500 | Loss: 1.68001 | Acc: 53.836% (21543/40016)
# Step: 2550 | Loss: 1.68054 | Acc: 53.812% (21964/40816)
# Step: 2600 | Loss: 1.68028 | Acc: 53.813% (22395/41616)
# Step: 2650 | Loss: 1.67923 | Acc: 53.817% (22827/42416)
# Step: 2700 | Loss: 1.67808 | Acc: 53.885% (23287/43216)
# Step: 2750 | Loss: 1.67885 | Acc: 53.874% (23713/44016)
# Step: 2800 | Loss: 1.67792 | Acc: 53.920% (24165/44816)
# Step: 2850 | Loss: 1.67884 | Acc: 53.891% (24583/45616)
# Step: 2900 | Loss: 1.68099 | Acc: 53.900% (25018/46416)
# Step: 2950 | Loss: 1.67997 | Acc: 53.941% (25469/47216)
# Step: 3000 | Loss: 1.67923 | Acc: 53.940% (25900/48016)
# Step: 3050 | Loss: 1.67793 | Acc: 53.952% (26337/48816)
# Step: 3100 | Loss: 1.67683 | Acc: 53.956% (26771/49616)
# Step: 3150 | Loss: 1.67770 | Acc: 53.947% (27198/50416)
# Step: 3200 | Loss: 1.67959 | Acc: 53.911% (27611/51216)
# Step: 3250 | Loss: 1.67981 | Acc: 53.933% (28054/52016)
# Step: 3300 | Loss: 1.68038 | Acc: 53.906% (28471/52816)
# Step: 3350 | Loss: 1.67951 | Acc: 53.909% (28904/53616)
# Step: 3400 | Loss: 1.67986 | Acc: 53.879% (29319/54416)
# Step: 3450 | Loss: 1.68003 | Acc: 53.890% (29756/55216)
# Step: 3500 | Loss: 1.68014 | Acc: 53.861% (30171/56016)
# Step: 3550 | Loss: 1.68056 | Acc: 53.844% (30592/56816)
# Step: 3600 | Loss: 1.67914 | Acc: 53.864% (31034/57616)
# Step: 3650 | Loss: 1.67902 | Acc: 53.840% (31451/58416)
# Step: 3700 | Loss: 1.67998 | Acc: 53.808% (31863/59216)
# Step: 3750 | Loss: 1.67840 | Acc: 53.841% (32313/60016)
# Step: 3800 | Loss: 1.67657 | Acc: 53.895% (32777/60816)
# Step: 3850 | Loss: 1.67578 | Acc: 53.908% (33216/61616)
# Step: 3900 | Loss: 1.67458 | Acc: 53.943% (33669/62416)
# Step: 3950 | Loss: 1.67418 | Acc: 53.917% (34084/63216)
# Step: 4000 | Loss: 1.67280 | Acc: 53.972% (34551/64016)
# Step: 4050 | Loss: 1.67031 | Acc: 54.036% (35024/64816)
# Step: 0 | Loss: 2.153 | Acc: 33.333% (1/3)
#
# Step: 50 | Loss: 2.303 | Acc: 37.908% (58/153)
#
# Step: 100 | Loss: 2.305 | Acc: 37.954% (115/303)
#
# Step: 150 | Loss: 2.346 | Acc: 36.645% (166/453)
#
# Step: 200 | Loss: 2.388 | Acc: 35.655% (215/603)
#
# Step: 250 | Loss: 2.426 | Acc: 34.396% (259/753)
#
# Step: 300 | Loss: 2.454 | Acc: 33.887% (306/903)
#
# Step: 350 | Loss: 2.436 | Acc: 34.758% (366/1053)
#
# Step: 400 | Loss: 2.432 | Acc: 35.411% (426/1203)
#
# Step: 450 | Loss: 2.435 | Acc: 35.846% (485/1353)
#
# Step: 500 | Loss: 2.441 | Acc: 35.662% (536/1503)
#
# Step: 550 | Loss: 2.443 | Acc: 35.753% (591/1653)
#
# Step: 600 | Loss: 2.443 | Acc: 35.607% (642/1803)
#
# Step: 650 | Loss: 2.442 | Acc: 35.791% (699/1953)
#
# Step: 700 | Loss: 2.436 | Acc: 35.996% (757/2103)
#
# Step: 750 | Loss: 2.432 | Acc: 36.573% (824/2253)
#
# Step: 800 | Loss: 2.437 | Acc: 36.163% (869/2403)
#
# Step: 850 | Loss: 2.440 | Acc: 35.919% (917/2553)
#
# Step: 900 | Loss: 2.436 | Acc: 35.923% (971/2703)
#
# Step: 950 | Loss: 2.431 | Acc: 36.102% (1030/2853)
#
# Step: 1000 | Loss: 2.425 | Acc: 36.097% (1084/3003)
#
# Step: 1050 | Loss: 2.425 | Acc: 36.093% (1138/3153)
#
# Step: 1100 | Loss: 2.431 | Acc: 35.786% (1182/3303)
#
# Step: 1150 | Loss: 2.424 | Acc: 35.766% (1235/3453)
#
# Step: 1200 | Loss: 2.420 | Acc: 35.859% (1292/3603)
#
# Step: 1250 | Loss: 2.418 | Acc: 35.731% (1341/3753)
#
# Step: 1300 | Loss: 2.424 | Acc: 35.716% (1394/3903)
#
# Step: 1350 | Loss: 2.420 | Acc: 35.702% (1447/4053)
#
# Step: 1400 | Loss: 2.416 | Acc: 35.784% (1504/4203)
#
# Step: 1450 | Loss: 2.422 | Acc: 35.654% (1552/4353)
#
# Step: 1500 | Loss: 2.422 | Acc: 35.510% (1599/4503)
#
# Step: 1550 | Loss: 2.413 | Acc: 35.654% (1659/4653)
#
# Step: 1600 | Loss: 2.409 | Acc: 35.665% (1713/4803)
#
# Step: 1650 | Loss: 2.407 | Acc: 35.554% (1761/4953)
#
# Step: 1700 | Loss: 2.402 | Acc: 35.900% (1832/5103)
#
#
# Epoch: 5
# Step: 0 | Loss: 1.36146 | Acc: 62.500% (10/16)
# Step: 50 | Loss: 1.63493 | Acc: 54.167% (442/816)
# Step: 100 | Loss: 1.67100 | Acc: 53.527% (865/1616)
# Step: 150 | Loss: 1.66432 | Acc: 53.725% (1298/2416)
# Step: 200 | Loss: 1.64604 | Acc: 54.229% (1744/3216)
# Step: 250 | Loss: 1.62784 | Acc: 54.706% (2197/4016)
# Step: 300 | Loss: 1.63108 | Acc: 54.755% (2637/4816)
# Step: 350 | Loss: 1.62578 | Acc: 54.843% (3080/5616)
# Step: 400 | Loss: 1.62931 | Acc: 55.065% (3533/6416)
# Step: 450 | Loss: 1.62393 | Acc: 55.100% (3976/7216)
# Step: 500 | Loss: 1.62497 | Acc: 55.027% (4411/8016)
# Step: 550 | Loss: 1.63059 | Acc: 54.775% (4829/8816)
# Step: 600 | Loss: 1.63473 | Acc: 54.742% (5264/9616)
# Step: 650 | Loss: 1.64225 | Acc: 54.522% (5679/10416)
# Step: 700 | Loss: 1.64270 | Acc: 54.511% (6114/11216)
# Step: 750 | Loss: 1.64141 | Acc: 54.602% (6561/12016)
# Step: 800 | Loss: 1.63794 | Acc: 54.666% (7006/12816)
# Step: 850 | Loss: 1.64117 | Acc: 54.509% (7422/13616)
# Step: 900 | Loss: 1.64316 | Acc: 54.481% (7854/14416)
# Step: 950 | Loss: 1.64471 | Acc: 54.449% (8285/15216)
# Step: 1000 | Loss: 1.64220 | Acc: 54.570% (8740/16016)
# Step: 1050 | Loss: 1.63794 | Acc: 54.698% (9198/16816)
# Step: 1100 | Loss: 1.63637 | Acc: 54.717% (9639/17616)
# Step: 1150 | Loss: 1.63304 | Acc: 54.838% (10099/18416)
# Step: 1200 | Loss: 1.63611 | Acc: 54.767% (10524/19216)
# Step: 1250 | Loss: 1.63214 | Acc: 54.876% (10984/20016)
# Step: 1300 | Loss: 1.63324 | Acc: 54.895% (11427/20816)
# Step: 1350 | Loss: 1.62916 | Acc: 55.001% (11889/21616)
# Step: 1400 | Loss: 1.62933 | Acc: 54.956% (12319/22416)
# Step: 1450 | Loss: 1.63146 | Acc: 54.928% (12752/23216)
# Step: 1500 | Loss: 1.62883 | Acc: 55.001% (13209/24016)
# Step: 1550 | Loss: 1.63080 | Acc: 54.961% (13639/24816)
# Step: 1600 | Loss: 1.63201 | Acc: 54.911% (14066/25616)
# Step: 1650 | Loss: 1.63064 | Acc: 54.861% (14492/26416)
# Step: 1700 | Loss: 1.63307 | Acc: 54.802% (14915/27216)
# Step: 1750 | Loss: 1.63100 | Acc: 54.915% (15385/28016)
# Step: 1800 | Loss: 1.63096 | Acc: 54.886% (15816/28816)
# Step: 1850 | Loss: 1.62948 | Acc: 54.923% (16266/29616)
# Step: 1900 | Loss: 1.62966 | Acc: 54.918% (16704/30416)
# Step: 1950 | Loss: 1.62949 | Acc: 54.892% (17135/31216)
# Step: 2000 | Loss: 1.62838 | Acc: 54.969% (17599/32016)
# Step: 2050 | Loss: 1.62595 | Acc: 55.007% (18051/32816)
# Step: 2100 | Loss: 1.62577 | Acc: 55.012% (18493/33616)
# Step: 2150 | Loss: 1.62571 | Acc: 55.027% (18938/34416)
# Step: 2200 | Loss: 1.62600 | Acc: 55.049% (19386/35216)
# Step: 2250 | Loss: 1.62303 | Acc: 55.117% (19851/36016)
# Step: 2300 | Loss: 1.62295 | Acc: 55.131% (20297/36816)
# Step: 2350 | Loss: 1.62173 | Acc: 55.168% (20752/37616)
# Step: 2400 | Loss: 1.62249 | Acc: 55.149% (21186/38416)
# Step: 2450 | Loss: 1.62343 | Acc: 55.184% (21641/39216)
# Step: 2500 | Loss: 1.62423 | Acc: 55.180% (22081/40016)
# Step: 2550 | Loss: 1.62566 | Acc: 55.096% (22488/40816)
# Step: 2600 | Loss: 1.62540 | Acc: 55.133% (22944/41616)
# Step: 2650 | Loss: 1.62382 | Acc: 55.184% (23407/42416)
# Step: 2700 | Loss: 1.62426 | Acc: 55.186% (23849/43216)
# Step: 2750 | Loss: 1.62452 | Acc: 55.207% (24300/44016)
# Step: 2800 | Loss: 1.62501 | Acc: 55.172% (24726/44816)
# Step: 2850 | Loss: 1.62546 | Acc: 55.147% (25156/45616)
# Step: 2900 | Loss: 1.62458 | Acc: 55.171% (25608/46416)
# Step: 2950 | Loss: 1.62583 | Acc: 55.155% (26042/47216)
# Step: 3000 | Loss: 1.62509 | Acc: 55.150% (26481/48016)
# Step: 3050 | Loss: 1.62597 | Acc: 55.142% (26918/48816)
# Step: 3100 | Loss: 1.62630 | Acc: 55.121% (27349/49616)
# Step: 3150 | Loss: 1.62479 | Acc: 55.147% (27803/50416)
# Step: 3200 | Loss: 1.62394 | Acc: 55.147% (28244/51216)
# Step: 3250 | Loss: 1.62405 | Acc: 55.137% (28680/52016)
# Step: 3300 | Loss: 1.62194 | Acc: 55.209% (29159/52816)
# Step: 3350 | Loss: 1.62241 | Acc: 55.187% (29589/53616)
# Step: 3400 | Loss: 1.62134 | Acc: 55.212% (30044/54416)
# Step: 3450 | Loss: 1.62105 | Acc: 55.189% (30473/55216)
# Step: 3500 | Loss: 1.61982 | Acc: 55.207% (30925/56016)
# Step: 3550 | Loss: 1.61863 | Acc: 55.212% (31369/56816)
# Step: 3600 | Loss: 1.61876 | Acc: 55.186% (31796/57616)
# Step: 3650 | Loss: 1.61769 | Acc: 55.202% (32247/58416)
# Step: 3700 | Loss: 1.61687 | Acc: 55.205% (32690/59216)
# Step: 3750 | Loss: 1.61543 | Acc: 55.230% (33147/60016)
# Step: 3800 | Loss: 1.61603 | Acc: 55.249% (33600/60816)
# Step: 3850 | Loss: 1.61561 | Acc: 55.271% (34056/61616)
# Step: 3900 | Loss: 1.61572 | Acc: 55.265% (34494/62416)
# Step: 3950 | Loss: 1.61487 | Acc: 55.299% (34958/63216)
# Step: 4000 | Loss: 1.61524 | Acc: 55.283% (35390/64016)
# Step: 4050 | Loss: 1.61578 | Acc: 55.270% (35824/64816)
# Step: 0 | Loss: 2.897 | Acc: 0.000% (0/3)
#
# Step: 50 | Loss: 2.519 | Acc: 32.026% (49/153)
#
# Step: 100 | Loss: 2.473 | Acc: 32.673% (99/303)
#
# Step: 150 | Loss: 2.450 | Acc: 32.450% (147/453)
#
# Step: 200 | Loss: 2.428 | Acc: 33.333% (201/603)
#
# Step: 250 | Loss: 2.382 | Acc: 34.529% (260/753)
#
# Step: 300 | Loss: 2.365 | Acc: 35.659% (322/903)
#
# Step: 350 | Loss: 2.335 | Acc: 36.087% (380/1053)
#
# Step: 400 | Loss: 2.317 | Acc: 37.157% (447/1203)
#
# Step: 450 | Loss: 2.319 | Acc: 37.546% (508/1353)
#
# Step: 500 | Loss: 2.314 | Acc: 37.525% (564/1503)
#
# Step: 550 | Loss: 2.307 | Acc: 37.326% (617/1653)
#
# Step: 600 | Loss: 2.302 | Acc: 37.327% (673/1803)
#
# Step: 650 | Loss: 2.305 | Acc: 37.174% (726/1953)
#
# Step: 700 | Loss: 2.312 | Acc: 36.567% (769/2103)
#
# Step: 750 | Loss: 2.317 | Acc: 36.973% (833/2253)
#
# Step: 800 | Loss: 2.317 | Acc: 37.162% (893/2403)
#
# Step: 850 | Loss: 2.314 | Acc: 37.094% (947/2553)
#
# Step: 900 | Loss: 2.311 | Acc: 37.514% (1014/2703)
#
# Step: 950 | Loss: 2.310 | Acc: 37.539% (1071/2853)
#
# Step: 1000 | Loss: 2.307 | Acc: 37.696% (1132/3003)
#
# Step: 1050 | Loss: 2.302 | Acc: 37.805% (1192/3153)
#
# Step: 1100 | Loss: 2.306 | Acc: 37.602% (1242/3303)
#
# Step: 1150 | Loss: 2.312 | Acc: 37.504% (1295/3453)
#
# Step: 1200 | Loss: 2.306 | Acc: 37.830% (1363/3603)
#
# Step: 1250 | Loss: 2.315 | Acc: 37.810% (1419/3753)
#
# Step: 1300 | Loss: 2.312 | Acc: 37.996% (1483/3903)
#
# Step: 1350 | Loss: 2.313 | Acc: 37.972% (1539/4053)
#
# Step: 1400 | Loss: 2.314 | Acc: 38.044% (1599/4203)
#
# Step: 1450 | Loss: 2.309 | Acc: 38.249% (1665/4353)
#
# Step: 1500 | Loss: 2.306 | Acc: 38.130% (1717/4503)
#
# Step: 1550 | Loss: 2.303 | Acc: 38.169% (1776/4653)
#
# Step: 1600 | Loss: 2.300 | Acc: 38.164% (1833/4803)
#
# Step: 1650 | Loss: 2.300 | Acc: 38.239% (1894/4953)
#
# Step: 1700 | Loss: 2.299 | Acc: 38.370% (1958/5103)
#
#
# Epoch: 6
# Step: 0 | Loss: 1.60256 | Acc: 50.000% (8/16)
# Step: 50 | Loss: 1.64489 | Acc: 55.637% (454/816)
# Step: 100 | Loss: 1.58091 | Acc: 57.116% (923/1616)
# Step: 150 | Loss: 1.58074 | Acc: 56.540% (1366/2416)
# Step: 200 | Loss: 1.56991 | Acc: 56.188% (1807/3216)
# Step: 250 | Loss: 1.57568 | Acc: 56.101% (2253/4016)
# Step: 300 | Loss: 1.58323 | Acc: 56.022% (2698/4816)
# Step: 350 | Loss: 1.57924 | Acc: 56.001% (3145/5616)
# Step: 400 | Loss: 1.58022 | Acc: 56.437% (3621/6416)
# Step: 450 | Loss: 1.58930 | Acc: 56.139% (4051/7216)
# Step: 500 | Loss: 1.58694 | Acc: 56.038% (4492/8016)
# Step: 550 | Loss: 1.58386 | Acc: 56.023% (4939/8816)
# Step: 600 | Loss: 1.57394 | Acc: 56.219% (5406/9616)
# Step: 650 | Loss: 1.57550 | Acc: 56.356% (5870/10416)
# Step: 700 | Loss: 1.57292 | Acc: 56.375% (6323/11216)
# Step: 750 | Loss: 1.56625 | Acc: 56.433% (6781/12016)
# Step: 800 | Loss: 1.56600 | Acc: 56.554% (7248/12816)
# Step: 850 | Loss: 1.56311 | Acc: 56.661% (7715/13616)
# Step: 900 | Loss: 1.56554 | Acc: 56.486% (8143/14416)
# Step: 950 | Loss: 1.56745 | Acc: 56.441% (8588/15216)
# Step: 1000 | Loss: 1.56713 | Acc: 56.462% (9043/16016)
# Step: 1050 | Loss: 1.56775 | Acc: 56.470% (9496/16816)
# Step: 1100 | Loss: 1.56270 | Acc: 56.613% (9973/17616)
# Step: 1150 | Loss: 1.56545 | Acc: 56.543% (10413/18416)
# Step: 1200 | Loss: 1.56688 | Acc: 56.469% (10851/19216)
# Step: 1250 | Loss: 1.56823 | Acc: 56.445% (11298/20016)
# Step: 1300 | Loss: 1.57145 | Acc: 56.385% (11737/20816)
# Step: 1350 | Loss: 1.57206 | Acc: 56.407% (12193/21616)
# Step: 1400 | Loss: 1.57217 | Acc: 56.424% (12648/22416)
# Step: 1450 | Loss: 1.57196 | Acc: 56.405% (13095/23216)
# Step: 1500 | Loss: 1.56582 | Acc: 56.571% (13586/24016)
# Step: 1550 | Loss: 1.56590 | Acc: 56.564% (14037/24816)
# Step: 1600 | Loss: 1.56521 | Acc: 56.558% (14488/25616)
# Step: 1650 | Loss: 1.56327 | Acc: 56.598% (14951/26416)
# Step: 1700 | Loss: 1.56106 | Acc: 56.662% (15421/27216)
# Step: 1750 | Loss: 1.55881 | Acc: 56.714% (15889/28016)
# Step: 1800 | Loss: 1.55739 | Acc: 56.670% (16330/28816)
# Step: 1850 | Loss: 1.55909 | Acc: 56.591% (16760/29616)
# Step: 1900 | Loss: 1.56066 | Acc: 56.585% (17211/30416)
# Step: 1950 | Loss: 1.56098 | Acc: 56.602% (17669/31216)
# Step: 2000 | Loss: 1.56084 | Acc: 56.612% (18125/32016)
# Step: 2050 | Loss: 1.56172 | Acc: 56.576% (18566/32816)
# Step: 2100 | Loss: 1.56523 | Acc: 56.476% (18985/33616)
# Step: 2150 | Loss: 1.56528 | Acc: 56.538% (19458/34416)
# Step: 2200 | Loss: 1.56725 | Acc: 56.480% (19890/35216)
# Step: 2250 | Loss: 1.56697 | Acc: 56.455% (20333/36016)
# Step: 2300 | Loss: 1.56544 | Acc: 56.440% (20779/36816)
# Step: 2350 | Loss: 1.56296 | Acc: 56.500% (21253/37616)
# Step: 2400 | Loss: 1.56389 | Acc: 56.489% (21701/38416)
# Step: 2450 | Loss: 1.56423 | Acc: 56.462% (22142/39216)
# Step: 2500 | Loss: 1.56568 | Acc: 56.437% (22584/40016)
# Step: 2550 | Loss: 1.56672 | Acc: 56.422% (23029/40816)
# Step: 2600 | Loss: 1.56523 | Acc: 56.471% (23501/41616)
# Step: 2650 | Loss: 1.56664 | Acc: 56.467% (23951/42416)
# Step: 2700 | Loss: 1.56619 | Acc: 56.444% (24393/43216)
# Step: 2750 | Loss: 1.56634 | Acc: 56.407% (24828/44016)
# Step: 2800 | Loss: 1.56519 | Acc: 56.424% (25287/44816)
# Step: 2850 | Loss: 1.56448 | Acc: 56.460% (25755/45616)
# Step: 2900 | Loss: 1.56518 | Acc: 56.470% (26211/46416)
# Step: 2950 | Loss: 1.56614 | Acc: 56.455% (26656/47216)
# Step: 3000 | Loss: 1.56687 | Acc: 56.421% (27091/48016)
# Step: 3050 | Loss: 1.56625 | Acc: 56.410% (27537/48816)
# Step: 3100 | Loss: 1.56678 | Acc: 56.395% (27981/49616)
# Step: 3150 | Loss: 1.56594 | Acc: 56.401% (28435/50416)
# Step: 3200 | Loss: 1.56598 | Acc: 56.406% (28889/51216)
# Step: 3250 | Loss: 1.56519 | Acc: 56.411% (29343/52016)
# Step: 3300 | Loss: 1.56625 | Acc: 56.377% (29776/52816)
# Step: 3350 | Loss: 1.56762 | Acc: 56.362% (30219/53616)
# Step: 3400 | Loss: 1.56590 | Acc: 56.406% (30694/54416)
# Step: 3450 | Loss: 1.56649 | Acc: 56.424% (31155/55216)
# Step: 3500 | Loss: 1.56533 | Acc: 56.457% (31625/56016)
# Step: 3550 | Loss: 1.56672 | Acc: 56.410% (32050/56816)
# Step: 3600 | Loss: 1.56600 | Acc: 56.418% (32506/57616)
# Step: 3650 | Loss: 1.56504 | Acc: 56.423% (32960/58416)
# Step: 3700 | Loss: 1.56621 | Acc: 56.422% (33411/59216)
# Step: 3750 | Loss: 1.56579 | Acc: 56.452% (33880/60016)
# Step: 3800 | Loss: 1.56445 | Acc: 56.483% (34351/60816)
# Step: 3850 | Loss: 1.56443 | Acc: 56.497% (34811/61616)
# Step: 3900 | Loss: 1.56513 | Acc: 56.465% (35243/62416)
# Step: 3950 | Loss: 1.56635 | Acc: 56.468% (35697/63216)
# Step: 4000 | Loss: 1.56574 | Acc: 56.495% (36166/64016)
# Step: 4050 | Loss: 1.56546 | Acc: 56.525% (36637/64816)
# Step: 0 | Loss: 2.746 | Acc: 33.333% (1/3)
#
# Step: 50 | Loss: 2.394 | Acc: 35.294% (54/153)
#
# Step: 100 | Loss: 2.432 | Acc: 35.314% (107/303)
#
# Step: 150 | Loss: 2.384 | Acc: 36.203% (164/453)
#
# Step: 200 | Loss: 2.402 | Acc: 35.323% (213/603)
#
# Step: 250 | Loss: 2.418 | Acc: 34.661% (261/753)
#
# Step: 300 | Loss: 2.392 | Acc: 36.213% (327/903)
#
# Step: 350 | Loss: 2.392 | Acc: 35.802% (377/1053)
#
# Step: 400 | Loss: 2.354 | Acc: 36.326% (437/1203)
#
# Step: 450 | Loss: 2.368 | Acc: 35.920% (486/1353)
#
# Step: 500 | Loss: 2.370 | Acc: 35.995% (541/1503)
#
# Step: 550 | Loss: 2.362 | Acc: 36.056% (596/1653)
#
# Step: 600 | Loss: 2.367 | Acc: 36.217% (653/1803)
#
# Step: 650 | Loss: 2.359 | Acc: 36.406% (711/1953)
#
# Step: 700 | Loss: 2.345 | Acc: 36.614% (770/2103)
#
# Step: 750 | Loss: 2.338 | Acc: 37.062% (835/2253)
#
# Step: 800 | Loss: 2.336 | Acc: 37.328% (897/2403)
#
# Step: 850 | Loss: 2.349 | Acc: 37.015% (945/2553)
#
# Step: 900 | Loss: 2.346 | Acc: 36.996% (1000/2703)
#
# Step: 950 | Loss: 2.341 | Acc: 36.698% (1047/2853)
#
# Step: 1000 | Loss: 2.336 | Acc: 36.563% (1098/3003)
#
# Step: 1050 | Loss: 2.330 | Acc: 36.727% (1158/3153)
#
# Step: 1100 | Loss: 2.331 | Acc: 36.694% (1212/3303)
#
# Step: 1150 | Loss: 2.327 | Acc: 36.924% (1275/3453)
#
# Step: 1200 | Loss: 2.331 | Acc: 36.803% (1326/3603)
#
# Step: 1250 | Loss: 2.331 | Acc: 36.851% (1383/3753)
#
# Step: 1300 | Loss: 2.335 | Acc: 36.741% (1434/3903)
#
# Step: 1350 | Loss: 2.341 | Acc: 36.763% (1490/4053)
#
# Step: 1400 | Loss: 2.337 | Acc: 37.021% (1556/4203)
#
# Step: 1450 | Loss: 2.337 | Acc: 36.894% (1606/4353)
#
# Step: 1500 | Loss: 2.336 | Acc: 36.975% (1665/4503)
#
# Step: 1550 | Loss: 2.333 | Acc: 36.944% (1719/4653)
#
# Step: 1600 | Loss: 2.338 | Acc: 36.790% (1767/4803)
#
# Step: 1650 | Loss: 2.342 | Acc: 36.544% (1810/4953)
#
# Step: 1700 | Loss: 2.341 | Acc: 36.606% (1868/5103)
#
#
# Epoch: 7
# Step: 0 | Loss: 1.24343 | Acc: 68.750% (11/16)
# Step: 50 | Loss: 1.46127 | Acc: 58.333% (476/816)
# Step: 100 | Loss: 1.47828 | Acc: 58.354% (943/1616)
# Step: 150 | Loss: 1.50080 | Acc: 57.823% (1397/2416)
# Step: 200 | Loss: 1.50228 | Acc: 57.991% (1865/3216)
# Step: 250 | Loss: 1.51457 | Acc: 57.644% (2315/4016)
# Step: 300 | Loss: 1.52270 | Acc: 57.330% (2761/4816)
# Step: 350 | Loss: 1.51327 | Acc: 57.496% (3229/5616)
# Step: 400 | Loss: 1.50693 | Acc: 57.949% (3718/6416)
# Step: 450 | Loss: 1.49954 | Acc: 57.982% (4184/7216)
# Step: 500 | Loss: 1.50271 | Acc: 57.984% (4648/8016)
# Step: 550 | Loss: 1.50386 | Acc: 58.008% (5114/8816)
# Step: 600 | Loss: 1.50630 | Acc: 57.831% (5561/9616)
# Step: 650 | Loss: 1.50570 | Acc: 57.969% (6038/10416)
# Step: 700 | Loss: 1.51090 | Acc: 57.775% (6480/11216)
# Step: 750 | Loss: 1.50711 | Acc: 57.781% (6943/12016)
# Step: 800 | Loss: 1.50897 | Acc: 57.826% (7411/12816)
# Step: 850 | Loss: 1.50842 | Acc: 57.873% (7880/13616)
# Step: 900 | Loss: 1.50674 | Acc: 57.859% (8341/14416)
# Step: 950 | Loss: 1.51167 | Acc: 57.775% (8791/15216)
# Step: 1000 | Loss: 1.51488 | Acc: 57.798% (9257/16016)
# Step: 1050 | Loss: 1.51768 | Acc: 57.653% (9695/16816)
# Step: 1100 | Loss: 1.51491 | Acc: 57.788% (10180/17616)
# Step: 1150 | Loss: 1.51200 | Acc: 57.808% (10646/18416)
# Step: 1200 | Loss: 1.51105 | Acc: 57.796% (11106/19216)
# Step: 1250 | Loss: 1.51349 | Acc: 57.809% (11571/20016)
# Step: 1300 | Loss: 1.51330 | Acc: 57.811% (12034/20816)
# Step: 1350 | Loss: 1.51226 | Acc: 57.726% (12478/21616)
# Step: 1400 | Loss: 1.51352 | Acc: 57.664% (12926/22416)
# Step: 1450 | Loss: 1.51038 | Acc: 57.697% (13395/23216)
# Step: 1500 | Loss: 1.51276 | Acc: 57.562% (13824/24016)
# Step: 1550 | Loss: 1.51203 | Acc: 57.560% (14284/24816)
# Step: 1600 | Loss: 1.51402 | Acc: 57.546% (14741/25616)
# Step: 1650 | Loss: 1.51499 | Acc: 57.526% (15196/26416)
# Step: 1700 | Loss: 1.51667 | Acc: 57.521% (15655/27216)
# Step: 1750 | Loss: 1.51598 | Acc: 57.492% (16107/28016)
# Step: 1800 | Loss: 1.51357 | Acc: 57.610% (16601/28816)
# Step: 1850 | Loss: 1.51571 | Acc: 57.587% (17055/29616)
# Step: 1900 | Loss: 1.51383 | Acc: 57.690% (17547/30416)
# Step: 1950 | Loss: 1.51489 | Acc: 57.669% (18002/31216)
# Step: 2000 | Loss: 1.51362 | Acc: 57.624% (18449/32016)
# Step: 2050 | Loss: 1.51605 | Acc: 57.548% (18885/32816)
# Step: 2100 | Loss: 1.51440 | Acc: 57.544% (19344/33616)
# Step: 2150 | Loss: 1.51407 | Acc: 57.595% (19822/34416)
# Step: 2200 | Loss: 1.51491 | Acc: 57.551% (20267/35216)
# Step: 2250 | Loss: 1.51374 | Acc: 57.566% (20733/36016)
# Step: 2300 | Loss: 1.51391 | Acc: 57.565% (21193/36816)
# Step: 2350 | Loss: 1.51324 | Acc: 57.569% (21655/37616)
# Step: 2400 | Loss: 1.51196 | Acc: 57.614% (22133/38416)
# Step: 2450 | Loss: 1.51010 | Acc: 57.678% (22619/39216)
# Step: 2500 | Loss: 1.51096 | Acc: 57.652% (23070/40016)
# Step: 2550 | Loss: 1.51037 | Acc: 57.673% (23540/40816)
# Step: 2600 | Loss: 1.51006 | Acc: 57.661% (23996/41616)
# Step: 2650 | Loss: 1.51073 | Acc: 57.627% (24443/42416)
# Step: 2700 | Loss: 1.51202 | Acc: 57.652% (24915/43216)
# Step: 2750 | Loss: 1.51137 | Acc: 57.686% (25391/44016)
# Step: 2800 | Loss: 1.51274 | Acc: 57.658% (25840/44816)
# Step: 2850 | Loss: 1.51288 | Acc: 57.607% (26278/45616)
# Step: 2900 | Loss: 1.51229 | Acc: 57.635% (26752/46416)
# Step: 2950 | Loss: 1.51089 | Acc: 57.667% (27228/47216)
# Step: 3000 | Loss: 1.50928 | Acc: 57.700% (27705/48016)
# Step: 3050 | Loss: 1.50935 | Acc: 57.688% (28161/48816)
# Step: 3100 | Loss: 1.50915 | Acc: 57.711% (28634/49616)
# Step: 3150 | Loss: 1.50961 | Acc: 57.706% (29093/50416)
# Step: 3200 | Loss: 1.50977 | Acc: 57.709% (29556/51216)
# Step: 3250 | Loss: 1.51024 | Acc: 57.680% (30003/52016)
# Step: 3300 | Loss: 1.50935 | Acc: 57.700% (30475/52816)
# Step: 3350 | Loss: 1.50902 | Acc: 57.682% (30927/53616)
# Step: 3400 | Loss: 1.50823 | Acc: 57.720% (31409/54416)
# Step: 3450 | Loss: 1.50732 | Acc: 57.766% (31896/55216)
# Step: 3500 | Loss: 1.50743 | Acc: 57.732% (32339/56016)
# Step: 3550 | Loss: 1.50710 | Acc: 57.757% (32815/56816)
# Step: 3600 | Loss: 1.50682 | Acc: 57.757% (33277/57616)
# Step: 3650 | Loss: 1.50757 | Acc: 57.734% (33726/58416)
# Step: 3700 | Loss: 1.50695 | Acc: 57.753% (34199/59216)
# Step: 3750 | Loss: 1.50702 | Acc: 57.741% (34654/60016)
# Step: 3800 | Loss: 1.50683 | Acc: 57.738% (35114/60816)
# Step: 3850 | Loss: 1.50785 | Acc: 57.730% (35571/61616)
# Step: 3900 | Loss: 1.50718 | Acc: 57.762% (36053/62416)
# Step: 3950 | Loss: 1.50756 | Acc: 57.750% (36507/63216)
# Step: 4000 | Loss: 1.50736 | Acc: 57.737% (36961/64016)
# Step: 4050 | Loss: 1.50718 | Acc: 57.770% (37444/64816)
# Step: 0 | Loss: 3.040 | Acc: 0.000% (0/3)
#
# Step: 50 | Loss: 2.436 | Acc: 33.987% (52/153)
#
# Step: 100 | Loss: 2.415 | Acc: 33.993% (103/303)
#
# Step: 150 | Loss: 2.365 | Acc: 35.099% (159/453)
#
# Step: 200 | Loss: 2.390 | Acc: 34.992% (211/603)
#
# Step: 250 | Loss: 2.397 | Acc: 35.193% (265/753)
#
# Step: 300 | Loss: 2.467 | Acc: 34.551% (312/903)
#
# Step: 350 | Loss: 2.491 | Acc: 34.283% (361/1053)
#
# Step: 400 | Loss: 2.494 | Acc: 34.414% (414/1203)
#
# Step: 450 | Loss: 2.464 | Acc: 34.664% (469/1353)
#
# Step: 500 | Loss: 2.452 | Acc: 34.997% (526/1503)
#
# Step: 550 | Loss: 2.445 | Acc: 35.209% (582/1653)
#
# Step: 600 | Loss: 2.446 | Acc: 35.219% (635/1803)
#
# Step: 650 | Loss: 2.441 | Acc: 35.330% (690/1953)
#
# Step: 700 | Loss: 2.455 | Acc: 34.998% (736/2103)
#
# Step: 750 | Loss: 2.462 | Acc: 34.976% (788/2253)
#
# Step: 800 | Loss: 2.451 | Acc: 35.081% (843/2403)
#
# Step: 850 | Loss: 2.453 | Acc: 34.861% (890/2553)
#
# Step: 900 | Loss: 2.450 | Acc: 34.554% (934/2703)
#
# Step: 950 | Loss: 2.448 | Acc: 34.490% (984/2853)
#
# Step: 1000 | Loss: 2.449 | Acc: 34.565% (1038/3003)
#
# Step: 1050 | Loss: 2.442 | Acc: 34.824% (1098/3153)
#
# Step: 1100 | Loss: 2.445 | Acc: 34.756% (1148/3303)
#
# Step: 1150 | Loss: 2.442 | Acc: 34.810% (1202/3453)
#
# Step: 1200 | Loss: 2.444 | Acc: 34.777% (1253/3603)
#
# Step: 1250 | Loss: 2.442 | Acc: 34.746% (1304/3753)
#
# Step: 1300 | Loss: 2.432 | Acc: 35.101% (1370/3903)
#
# Step: 1350 | Loss: 2.434 | Acc: 35.307% (1431/4053)
#
# Step: 1400 | Loss: 2.437 | Acc: 35.118% (1476/4203)
#
# Step: 1450 | Loss: 2.436 | Acc: 35.171% (1531/4353)
#
# Step: 1500 | Loss: 2.436 | Acc: 35.265% (1588/4503)
#
# Step: 1550 | Loss: 2.432 | Acc: 35.311% (1643/4653)
#
# Step: 1600 | Loss: 2.439 | Acc: 35.082% (1685/4803)
#
# Step: 1650 | Loss: 2.440 | Acc: 35.090% (1738/4953)
#
# Step: 1700 | Loss: 2.433 | Acc: 35.273% (1800/5103)
#
#
# Epoch: 8
# Step: 0 | Loss: 0.79500 | Acc: 75.000% (12/16)
# Step: 50 | Loss: 1.45438 | Acc: 58.824% (480/816)
# Step: 100 | Loss: 1.41258 | Acc: 60.149% (972/1616)
# Step: 150 | Loss: 1.46142 | Acc: 59.644% (1441/2416)
# Step: 200 | Loss: 1.45336 | Acc: 59.888% (1926/3216)
# Step: 250 | Loss: 1.47272 | Acc: 59.014% (2370/4016)
# Step: 300 | Loss: 1.47764 | Acc: 58.700% (2827/4816)
# Step: 350 | Loss: 1.47228 | Acc: 59.081% (3318/5616)
# Step: 400 | Loss: 1.46886 | Acc: 59.227% (3800/6416)
# Step: 450 | Loss: 1.46981 | Acc: 59.202% (4272/7216)
# Step: 500 | Loss: 1.45985 | Acc: 59.182% (4744/8016)
# Step: 550 | Loss: 1.45733 | Acc: 59.301% (5228/8816)
# Step: 600 | Loss: 1.45534 | Acc: 59.370% (5709/9616)
# Step: 650 | Loss: 1.45646 | Acc: 59.284% (6175/10416)
# Step: 700 | Loss: 1.45817 | Acc: 59.174% (6637/11216)
# Step: 750 | Loss: 1.46050 | Acc: 59.154% (7108/12016)
# Step: 800 | Loss: 1.46081 | Acc: 59.098% (7574/12816)
# Step: 850 | Loss: 1.45893 | Acc: 59.085% (8045/13616)
# Step: 900 | Loss: 1.45889 | Acc: 59.219% (8537/14416)
# Step: 950 | Loss: 1.45771 | Acc: 59.253% (9016/15216)
# Step: 1000 | Loss: 1.45586 | Acc: 59.391% (9512/16016)
# Step: 1050 | Loss: 1.45383 | Acc: 59.426% (9993/16816)
# Step: 1100 | Loss: 1.45148 | Acc: 59.503% (10482/17616)
# Step: 1150 | Loss: 1.45153 | Acc: 59.454% (10949/18416)
# Step: 1200 | Loss: 1.45087 | Acc: 59.487% (11431/19216)
# Step: 1250 | Loss: 1.44999 | Acc: 59.527% (11915/20016)
# Step: 1300 | Loss: 1.44451 | Acc: 59.608% (12408/20816)
# Step: 1350 | Loss: 1.44300 | Acc: 59.604% (12884/21616)
# Step: 1400 | Loss: 1.44344 | Acc: 59.547% (13348/22416)
# Step: 1450 | Loss: 1.44524 | Acc: 59.524% (13819/23216)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-048f4933fe2a> in <module>()
#      29         testloader=test_loader,
#      30         batch_size_test=batchSize_test,
# ---> 31         in_net=irnet_in
#      32         )
#
# <ipython-input-9-ab1176a7f576> in train(nb_epoch, batch_size, store_name, resume, start_epoch, model_path, trainloader, testloader, batch_size_test, in_net)
#      79             loss = CELoss(output_p, targets) * 1
#      80             loss.backward()
# ---> 81             optimizer.step()
#      82
#      83             #  training log
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      63                 instance._step_count += 1
#      64                 wrapped = func.__get__(instance, cls)
# ---> 65                 return wrapped(*args, **kwargs)
#      66
#      67             # Note that the returned function here is no longer a bound method,
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/sgd.py in step(self, closure)
#     150                   dampening=dampening,
#     151                   nesterov=nesterov,
# --> 152                   maximize=maximize,)
#     153
#     154             # update momentum_buffers in state
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/_functional.py in sgd(params, d_p_list, momentum_buffer_list, weight_decay, momentum, lr, dampening, nesterov, maximize)
#     184                 momentum_buffer_list[i] = buf
#     185             else:
# --> 186                 buf.mul_(momentum).add_(d_p, alpha=1 - dampening)
#     187
#     188             if nesterov:
#
# KeyboardInterrupt:

# %% [markdown]
# # \* **Debug & adjustment**

# %%
# ##checking gpu:
# ##memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize

# import psutil
# import humanize
# import os
# import GPUtil as GPU

# GPUs = GPU.getGPUs()
# ##XXX: only one GPU on Colab and isn’t guaranteed
# gpu = GPUs[0]
# def printm():
#     process = psutil.Process(os.getpid())
#     print("Gen RAM Free: " + humanize.naturalsize(psutil.virtual_memory().available), " |     Proc size: " + humanize.naturalsize(process.memory_info().rss))
#     print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total     {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
# printm()

# %%
# ##model debug and adjustment 

# temp_net = build_model()
# temp_net.load_state_dict(torch.load(modelPath))
# linear_in_features = temp_net.linear_cls.weight.size()[1]
# linear_out_features = 130
# new_linear_cls = nn.Linear(linear_in_features, linear_out_features)
# new_linear_cls.weight.data = temp_net.linear_cls.weight.data[:linear_out_features]
# new_linear_cls.bias.data = temp_net.linear_cls.bias.data[:linear_out_features]
# temp_net.linear_cls = new_linear_cls

# %%
# storePath = '/content/drive/MyDrive/CSCE5218/Dog_Breed_classification/output'
# modelName = '/model_irnetv2_130cls.pth'
# modelPath = storePath + modelName
# temp_net.cpu()
# torch.save(temp_net.state_dict(), modelPath)

# %%
# #clean memory in case GPU memory is fragmented
# torch.cuda.empty_cache() 

# # ##
# trained_net, trained_loss = train(nb_epoch=20,             # number of epoch
#         batch_size=batchSize_train,         # batch size
#         store_name=store_path,     # folder for output
#         resume=True,          # resume training from checkpoint
#         start_epoch=startEpoch,         # the start epoch number when you resume the training
#         model_path=modelPath,         # the saved model where you want to resume the training
#         trainloader=train_loader,
#         testloader=test_loader,
#         batch_size_test=batchSize_test,
#         in_net=temp_net
#         )
